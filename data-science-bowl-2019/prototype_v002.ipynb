# %%
import numpy as np
import pandas as pd
pd.set_option('max_columns', 150)
import os

from collections import Counter
from tqdm import tqdm_notebook as tqdm
from sklearn.model_selection import KFold, StratifiedKFold
import tensorflow as tf

# %%
for _, _, files in os.walk('/input/data-science-bowl-2019'):
    print(files)
# Out:
# ['sample_submission.csv', 'specs.csv', 'test.csv', 'train.csv', 'train_labels.csv']

# %%
def read_csv():
    BASE_PATH = '/input/data-science-bowl-2019/'
    #train
    print('Reading train.csv as DataFrame...')
    train = pd.read_csv(BASE_PATH + 'train.csv')
    print('Completed, train have {} columns, {} rows.'.format(train.shape[0], train.shape[1]))
    #train_lebels
    print('Reading train_labels.csv as DataFrame...')
    train_labels = pd.read_csv(BASE_PATH + 'train_labels.csv')
    print('Completed, train_labels have {} columns, {} rows.'.format(train_labels.shape[0], train_labels.shape[1]))
    #test
    print('Reading test.csv as DataFrame...')
    test = pd.read_csv(BASE_PATH + 'test.csv')
    print('Completed, test have {} columns, {} rows.'.format(test.shape[0], test.shape[1]))
    #specs
    print('Reading specs.csv as DataFrame...')
    specs = pd.read_csv(BASE_PATH + 'specs.csv')
    print('Completed, specs have {} columns, {} rows.'.format(specs.shape[0], specs.shape[1]))
    #sample_submission
    print('Reading sample_submission.csv as DataFrame...')
    sample_submission = pd.read_csv(BASE_PATH + 'sample_submission.csv')
    print('Completed, sample_submission have {} columns, {} rows.'.format(sample_submission.shape[0], sample_submission.shape[1]))
    
    return train, train_labels, test, specs, sample_submission

# %%
def feature_encoder(train, test):
    print('Encoding feature...')
    train['title_event_code'] = list(map(lambda x, y: str(x) + '_' + str(y), train['title'], train['event_code']))
    test['title_event_code'] = list(map(lambda x, y: str(x) + '_' + str(y), test['title'], test['event_code']))
    train['world_type'] = list(map(lambda x, y: str(x) + '_' + str(y), train['world'], train['type']))
    test['world_type'] = list(map(lambda x, y: str(x) + '_' + str(y), test['world'], test['type']))
    
    def encoder(feature):
        list_ = list(set(train[feature].unique()).union(set(test[feature].unique())))
        map_ = dict(zip(list_, np.arange(len(list_))))
        labels = dict(zip(np.arange(len(list_)), list_))
        return list_, map_, labels
    
    title_list, title_map, title_labels = encoder('title')
    world_list, world_map, world_labels = encoder('world')
    eventId_list, _, _ = encoder('event_id')
    eventCode_list, _, _ = encoder('event_code')
    title_eventCode_list, _, _ = encoder('title_event_code')
    world_type_list, _, _ = encoder('world_type')
    asses_title_list = list(set(train[train.type == 'Assessment']['title'].unique()).union(set(test[test.type == 'Assessment']['title'].unique())))

    train['title'] = train['title'].map(title_map)
    test['title'] = test['title'].map(title_map)
    train['world'] = train['world'].map(world_map)
    test['world'] = test['world'].map(world_map)
    print('Encoding completed.')
    return train, test, title_list, title_map, title_labels, world_list, world_map, world_labels, eventId_list, eventCode_list, title_eventCode_list, world_type_list, asses_title_list

# %%
def read_data(df, test_set=False):
    #count
    type_count = {'Clip': 0, 'Activity': 0, 'Assessment': 0, 'Game': 0}
    asses_count = {'acc_all': 0, 'acc_true': 0, 'acc_false': 0}
    group_count = {n: 0 for n in np.arange(4)}
    title_count = {ti: 0 for ti in title_list}
    world_count = {wo: 0 for wo in world_list}
    assesTrue_title_count = {at: 0 for at in asses_title_list}
    assesFalse_title_count = {af: 0 for af in asses_title_list}
    eventId_count = {ei: 0 for ei in eventId_list}
    eventCode_count = {ec: 0 for ec in eventCode_list}
    title_eventCode_count = {te: 0 for te in title_eventCode_list}
    world_type_count = {wt: 0 for wt in world_type_list}
    #time count
    title_time = {str(ti)+'_t': 0 for ti in title_list}
    world_time = {str(wo)+'_t': 0 for wo in world_list}
    
    features = []
    mean_time = []
    acc_time = 0
    assess_attempt_code = [4100, 4110]
    
    for i, sess in df.groupby('game_session', sort=False):
        title = sess.title.iloc[0]
        world = sess.world.iloc[0]
        sess_type = sess.type.iloc[0]
        time = int(sess.game_time.iloc[-1] / 1000)
        
        if sess_type != 'Assessment':
            acc_time += time
        
        if (sess_type == 'Assessment') & (test_set or len(sess) > 1):
            
            feature = type_count.copy()
            feature['installation_id'] = sess.installation_id.iloc[0]
            feature['title'] = title
            feature['true_record'] = assesTrue_title_count[title_labels[title]]
            feature['false_record'] = assesFalse_title_count[title_labels[title]]
            feature['acc_play_time'] = acc_time
            
            #time
            if mean_time == []:
                feature['asses_time_mean'] = 0
                feature['asses_time_std'] = 0
            else:
                feature['asses_time_mean'] = np.mean(mean_time)
                feature['asses_time_std'] = np.std(mean_time)
            mean_time.append((sess.game_time.iloc[-1] - sess.game_time.iloc[0])/1000)
                
            #accuracy
            attempt_all = sess[(sess.event_code == 4100) | (sess.event_code == 4110)]['event_data'].shape[0]
            attempt_true = sess[(sess.event_code == 4100) | (sess.event_code == 4110)]['event_data'].str.contains('true').sum()
            attempt_false = sess[(sess.event_code == 4100) | (sess.event_code == 4110)]['event_data'].str.contains('false').sum()
            accuracy_rate = attempt_true / attempt_all if attempt_all != 0 else 0
            if accuracy_rate == 0:
                feature['accuracy_group'] = 0
            elif accuracy_rate == 1:
                feature['accuracy_group'] = 3
            elif accuracy_rate == 0.5:
                feature['accuracy_group'] = 2
            else:
                feature['accuracy_group'] = 1
            feature['acc_accuracy'] = asses_count['acc_true'] / asses_count['acc_all'] if asses_count['acc_all'] != 0 else 0
            feature.update(group_count)
            group_count[feature['accuracy_group']] += 1
            feature.update(asses_count)
            asses_count['acc_all'] += attempt_all 
            asses_count['acc_true'] += attempt_true
            asses_count['acc_false'] += attempt_false
            assesTrue_title_count[title_labels[title]] = attempt_true
            assesFalse_title_count[title_labels[title]] = attempt_false
            
            #Update count
            feature.update(title_count)
            feature.update(world_count)
            feature.update(eventId_count)
            feature.update(eventCode_count)
            feature.update(title_eventCode_count)
            feature.update(world_type_count)
            
            variety_features = [('var_event_code', eventCode_count),
                                ('var_event_id', eventId_count),
                                ('var_title', title_count),
                                ('var_title_event_code', title_eventCode_count)]
            
            for name, dict_counts in variety_features:
                arr = np.array(list(dict_counts.values()))
                feature[name] = np.count_nonzero(arr)
            
            #Update acctime
            feature.update(title_time)
            feature.update(world_time)
            
            if test_set:
                features = feature
            else:
                features.append(feature)
                
        #count
        type_count[sess_type] += 1
        title_count[title_labels[title]] += 1
        world_count[world_labels[world]] += 1
            
        def count_updater(dic ,col):
            num_of_counter = Counter(sess[col])
            for i in num_of_counter.keys():
                dic[i] += num_of_counter[i]
                
        count_updater(eventId_count, 'event_id')
        count_updater(eventCode_count, 'event_code')
        count_updater(title_eventCode_count, 'title_event_code')
        count_updater(world_type_count, 'world_type')
        
        #acctime
        title_time[str(title_labels[title]) + '_t'] += time
        world_time[str(world_labels[world]) + '_t'] += time
    
    return features

# %%
def get_train_test(train, test):
    all_train = []
    all_test = []
    print('Getting train_encoder data...')
    for ins_id, data in tqdm(train.groupby('installation_id', sort=False), total=train.installation_id.nunique(), desc='installation_id'):
        all_train += read_data(data)
    print('Completed of train_en.')
    print('Getting test_encoder data...')
    for ins_id, data in tqdm(test.groupby('installation_id', sort=False), total=test.installation_id.nunique(), desc='installation_id'):
        tt = read_data(data, test_set=True)
        all_test.append(tt)
    print('Completed of test_en.')
    train_en = pd.DataFrame(all_train)
    test_en = pd.DataFrame(all_test)
    return train_en, test_en

# %%
def preprocess(train_en, test_en):
    for df in [train_en, test_en]:
        df['installation_session_count'] = df.groupby('installation_id')['Clip'].transform('count')
        df['installation_duration_time'] = df.groupby('installation_id')['asses_time_mean'].transform('mean')
        df['installation_title_nunique'] = df.groupby('installation_id')['title'].transform('nunique')
        
    return train_en, test_en

# %%
train, train_labels, test, specs, sample_submission = read_csv()
# Out:
# Reading train.csv as DataFrame...
# Completed, train have 11341042 columns, 11 rows.
# Reading train_labels.csv as DataFrame...
# Completed, train_labels have 17690 columns, 7 rows.
# Reading test.csv as DataFrame...
# Completed, test have 1156414 columns, 11 rows.
# Reading specs.csv as DataFrame...
# Completed, specs have 386 columns, 3 rows.
# Reading sample_submission.csv as DataFrame...
# Completed, sample_submission have 1000 columns, 2 rows.

# %%
keep_id = train[train.type == "Assessment"][['installation_id']].drop_duplicates()
train = pd.merge(train, keep_id, on="installation_id", how="inner")
print(f'remove installation_id which never made assessment')
print(f'reduce train to: {train.shape[0]} columns')
# Out:
# remove installation_id which never made assessment
# reduce train to: 8294138 columns

# %%
train, test, title_list, title_map, title_labels, world_list, world_map, world_labels, eventId_list, eventCode_list, title_eventCode_list, world_type_list, asses_title_list = feature_encoder(train, test)
train_en, test_en = get_train_test(train, test)
# Out:
# Encoding feature...
# Encoding completed.
# Getting train_encoder data...
# HBox(children=(IntProgress(value=0, description='installation_id', max=4242, style=ProgressStyle(description_w…
# Completed of train_en.
# Getting test_encoder data...
# HBox(children=(IntProgress(value=0, description='installation_id', max=1000, style=ProgressStyle(description_w…
# Completed of test_en.

# %%
train_en, test_en = preprocess(train_en, test_en)

# %%
features = train_en.loc[(train_en.sum(axis=1) != 0), (train_en.sum(axis=0) != 0)].columns
features = [col for col in features if col not in ['accuracy_group', 'installation_id']]
categoricals = ['session_title']

# %%
counter = 0
to_remove = []
for feat_1 in features:
    for feat_2 in features:
        if feat_1 != feat_2 and feat_1 not in to_remove and feat_2 not in to_remove:
            corr = np.corrcoef(train_en[feat_1], train_en[feat_2])[0][1]
            if corr > 0.995:
                counter += 1
                to_remove.append(feat_2)
                print('{}: FEAT_1: {} FEAT_2: {} - Correlation: {}'.format(counter, feat_1, feat_2, corr))
# Out:
# 1: FEAT_1: Clip FEAT_2: 27253bdc - Correlation: 1.0
# 2: FEAT_1: Bird Measurer (Assessment) FEAT_2: f56e0afc - Correlation: 1.0
# 3: FEAT_1: Bird Measurer (Assessment) FEAT_2: Bird Measurer (Assessment)_2000 - Correlation: 1.0
# 4: FEAT_1: Happy Camel FEAT_2: d9c005dd - Correlation: 1.0
# 5: FEAT_1: Happy Camel FEAT_2: Happy Camel_2000 - Correlation: 1.0
# 6: FEAT_1: Crystal Caves - Level 3 FEAT_2: Crystal Caves - Level 3_2000 - Correlation: 0.9999999999999999
# 7: FEAT_1: Crystal Caves - Level 2 FEAT_2: Crystal Caves - Level 2_2000 - Correlation: 0.9999999999999999
# 8: FEAT_1: Mushroom Sorter (Assessment) FEAT_2: db02c830 - Correlation: 0.9999988147664092
# 9: FEAT_1: Mushroom Sorter (Assessment) FEAT_2: 3bfd1a65 - Correlation: 1.0
# 10: FEAT_1: Mushroom Sorter (Assessment) FEAT_2: Mushroom Sorter (Assessment)_2025 - Correlation: 0.9999988147664092
# 11: FEAT_1: Mushroom Sorter (Assessment) FEAT_2: Mushroom Sorter (Assessment)_2000 - Correlation: 1.0
# 12: FEAT_1: Flower Waterer (Activity) FEAT_2: 9b01374f - Correlation: 1.0
# 13: FEAT_1: Flower Waterer (Activity) FEAT_2: Flower Waterer (Activity)_2000 - Correlation: 1.0
# 14: FEAT_1: Chow Time FEAT_2: 7d093bf9 - Correlation: 1.0
# 15: FEAT_1: Chow Time FEAT_2: Chow Time_2000 - Correlation: 1.0
# 16: FEAT_1: 12 Monkeys FEAT_2: 12 Monkeys_2000 - Correlation: 1.0
# 17: FEAT_1: Balancing Act FEAT_2: Balancing Act_2000 - Correlation: 1.0
# 18: FEAT_1: All Star Sorting FEAT_2: 4b5efe37 - Correlation: 0.9979870590228768
# 19: FEAT_1: All Star Sorting FEAT_2: b7dc8128 - Correlation: 0.9999999999999999
# 20: FEAT_1: All Star Sorting FEAT_2: All Star Sorting_4010 - Correlation: 0.9979870590228768
# 21: FEAT_1: All Star Sorting FEAT_2: All Star Sorting_2000 - Correlation: 0.9999999999999999
# 22: FEAT_1: Bug Measurer (Activity) FEAT_2: c7f7f0e1 - Correlation: 1.0
# 23: FEAT_1: Bug Measurer (Activity) FEAT_2: Bug Measurer (Activity)_2000 - Correlation: 1.0
# 24: FEAT_1: Tree Top City - Level 1 FEAT_2: Tree Top City - Level 1_2000 - Correlation: 0.9999999999999999
# 25: FEAT_1: Chicken Balancer (Activity) FEAT_2: 756e5507 - Correlation: 0.9999999999999998
# 26: FEAT_1: Chicken Balancer (Activity) FEAT_2: Chicken Balancer (Activity)_2000 - Correlation: 0.9999999999999998
# 27: FEAT_1: Magma Peak - Level 1 FEAT_2: Magma Peak - Level 1_2000 - Correlation: 1.0
# 28: FEAT_1: Magma Peak - Level 2 FEAT_2: Magma Peak - Level 2_2000 - Correlation: 1.0
# 29: FEAT_1: Watering Hole (Activity) FEAT_2: e64e2cfd - Correlation: 0.9999999999999998
# 30: FEAT_1: Watering Hole (Activity) FEAT_2: Watering Hole (Activity)_2000 - Correlation: 0.9999999999999998
# 31: FEAT_1: Welcome to Lost Lagoon! FEAT_2: NONE - Correlation: 1.0
# 32: FEAT_1: Welcome to Lost Lagoon! FEAT_2: Welcome to Lost Lagoon!_2000 - Correlation: 1.0
# 33: FEAT_1: Welcome to Lost Lagoon! FEAT_2: NONE_Clip - Correlation: 1.0
# 34: FEAT_1: Bubble Bath FEAT_2: 1cf54632 - Correlation: 1.0
# 35: FEAT_1: Bubble Bath FEAT_2: Bubble Bath_2000 - Correlation: 1.0
# 36: FEAT_1: Dino Dive FEAT_2: 29bdd9ba - Correlation: 0.9999999999999998
# 37: FEAT_1: Dino Dive FEAT_2: Dino Dive_2000 - Correlation: 0.9999999999999998
# 38: FEAT_1: Dino Drink FEAT_2: 51311d7a - Correlation: 0.9999999999999998
# 39: FEAT_1: Dino Drink FEAT_2: Dino Drink_2000 - Correlation: 0.9999999999999998
# 40: FEAT_1: Pirate's Tale FEAT_2: Pirate's Tale_2000 - Correlation: 1.0
# 41: FEAT_1: Crystals Rule FEAT_2: 48349b14 - Correlation: 1.0
# 42: FEAT_1: Crystals Rule FEAT_2: Crystals Rule_2000 - Correlation: 1.0
# 43: FEAT_1: Rulers FEAT_2: Rulers_2000 - Correlation: 0.9999999999999998
# 44: FEAT_1: Ordering Spheres FEAT_2: Ordering Spheres_2000 - Correlation: 1.0
# 45: FEAT_1: Costume Box FEAT_2: Costume Box_2000 - Correlation: 1.0
# 46: FEAT_1: Slop Problem FEAT_2: Slop Problem_2000 - Correlation: 1.0
# 47: FEAT_1: Lifting Heavy Things FEAT_2: Lifting Heavy Things_2000 - Correlation: 1.0
# 48: FEAT_1: Egg Dropper (Activity) FEAT_2: 736f9581 - Correlation: 0.9999893817564391
# 49: FEAT_1: Egg Dropper (Activity) FEAT_2: 9b23e8ee - Correlation: 0.9999999999999998
# 50: FEAT_1: Egg Dropper (Activity) FEAT_2: Egg Dropper (Activity)_2020 - Correlation: 0.9999893817564391
# 51: FEAT_1: Egg Dropper (Activity) FEAT_2: Egg Dropper (Activity)_2000 - Correlation: 0.9999999999999998
# 52: FEAT_1: Air Show FEAT_2: 15ba1109 - Correlation: 0.9999999999999999
# 53: FEAT_1: Air Show FEAT_2: Air Show_2000 - Correlation: 0.9999999999999999
# 54: FEAT_1: Fireworks (Activity) FEAT_2: 4901243f - Correlation: 1.0
# 55: FEAT_1: Fireworks (Activity) FEAT_2: Fireworks (Activity)_2000 - Correlation: 1.0
# 56: FEAT_1: Sandcastle Builder (Activity) FEAT_2: 77261ab5 - Correlation: 0.9999999999999999
# 57: FEAT_1: Sandcastle Builder (Activity) FEAT_2: Sandcastle Builder (Activity)_2000 - Correlation: 0.9999999999999999
# 58: FEAT_1: Chest Sorter (Assessment) FEAT_2: 155f62a4 - Correlation: 1.0
# 59: FEAT_1: Chest Sorter (Assessment) FEAT_2: 5b49460a - Correlation: 1.0
# 60: FEAT_1: Chest Sorter (Assessment) FEAT_2: Chest Sorter (Assessment)_2000 - Correlation: 1.0
# 61: FEAT_1: Chest Sorter (Assessment) FEAT_2: Chest Sorter (Assessment)_2020 - Correlation: 1.0
# 62: FEAT_1: Leaf Leader FEAT_2: 8ac7cce4 - Correlation: 1.0
# 63: FEAT_1: Leaf Leader FEAT_2: Leaf Leader_2000 - Correlation: 1.0
# 64: FEAT_1: Treasure Map FEAT_2: Treasure Map_2000 - Correlation: 1.0
# 65: FEAT_1: Bottle Filler (Activity) FEAT_2: d2278a3b - Correlation: 1.0
# 66: FEAT_1: Bottle Filler (Activity) FEAT_2: Bottle Filler (Activity)_2000 - Correlation: 1.0
# 67: FEAT_1: Tree Top City - Level 3 FEAT_2: Tree Top City - Level 3_2000 - Correlation: 0.9999999999999999
# 68: FEAT_1: Honey Cake FEAT_2: Honey Cake_2000 - Correlation: 0.9999999999999999
# 69: FEAT_1: Crystal Caves - Level 1 FEAT_2: Crystal Caves - Level 1_2000 - Correlation: 1.0
# 70: FEAT_1: Cart Balancer (Assessment) FEAT_2: 65a38bf7 - Correlation: 0.9999711393261618
# 71: FEAT_1: Cart Balancer (Assessment) FEAT_2: 7ad3efc6 - Correlation: 1.0
# 72: FEAT_1: Cart Balancer (Assessment) FEAT_2: Cart Balancer (Assessment)_2000 - Correlation: 1.0
# 73: FEAT_1: Cart Balancer (Assessment) FEAT_2: Cart Balancer (Assessment)_2020 - Correlation: 0.9999711393261618
# 74: FEAT_1: Scrub-A-Dub FEAT_2: 6d90d394 - Correlation: 1.0
# 75: FEAT_1: Scrub-A-Dub FEAT_2: Scrub-A-Dub_2000 - Correlation: 1.0
# 76: FEAT_1: Heavy, Heavier, Heaviest FEAT_2: Heavy, Heavier, Heaviest_2000 - Correlation: 0.9999999999999998
# 77: FEAT_1: Tree Top City - Level 2 FEAT_2: Tree Top City - Level 2_2000 - Correlation: 1.0
# 78: FEAT_1: Pan Balance FEAT_2: 9c5ef70c - Correlation: 1.0
# 79: FEAT_1: Pan Balance FEAT_2: Pan Balance_2000 - Correlation: 1.0
# 80: FEAT_1: Cauldron Filler (Assessment) FEAT_2: 90d848e0 - Correlation: 1.0
# 81: FEAT_1: Cauldron Filler (Assessment) FEAT_2: Cauldron Filler (Assessment)_2000 - Correlation: 1.0
# 82: FEAT_1: e4f1efe6 FEAT_2: 3afb49e6 - Correlation: 0.9985359088062646
# 83: FEAT_1: e4f1efe6 FEAT_2: 38074c54 - Correlation: 0.9984262994314632
# 84: FEAT_1: e4f1efe6 FEAT_2: 222660ff - Correlation: 0.9984262994314632
# 85: FEAT_1: e4f1efe6 FEAT_2: Chest Sorter (Assessment)_2030 - Correlation: 0.9984262994314632
# 86: FEAT_1: e4f1efe6 FEAT_2: Chest Sorter (Assessment)_3021 - Correlation: 0.9985359088062646
# 87: FEAT_1: e4f1efe6 FEAT_2: Chest Sorter (Assessment)_3121 - Correlation: 0.9999999999999998
# 88: FEAT_1: e4f1efe6 FEAT_2: Chest Sorter (Assessment)_2010 - Correlation: 0.9984262994314632
# 89: FEAT_1: 5e109ec3 FEAT_2: Cart Balancer (Assessment)_4030 - Correlation: 0.9999999999999999
# 90: FEAT_1: f50fc6c1 FEAT_2: Watering Hole (Activity)_4021 - Correlation: 1.0
# 91: FEAT_1: 47026d5f FEAT_2: cb6010f8 - Correlation: 0.999713467328076
# 92: FEAT_1: 47026d5f FEAT_2: 56817e2b - Correlation: 0.9992611702957377
# 93: FEAT_1: 47026d5f FEAT_2: Chow Time_3021 - Correlation: 0.9999999999999998
# 94: FEAT_1: 47026d5f FEAT_2: Chow Time_3121 - Correlation: 0.999713467328076
# 95: FEAT_1: 47026d5f FEAT_2: Chow Time_2030 - Correlation: 0.9992611702957377
# 96: FEAT_1: 7fd1ac25 FEAT_2: Egg Dropper (Activity)_4080 - Correlation: 1.0
# 97: FEAT_1: 31973d56 FEAT_2: 5de79a6a - Correlation: 0.9972032753730792
# 98: FEAT_1: 31973d56 FEAT_2: Cart Balancer (Assessment)_3120 - Correlation: 0.9999999999999999
# 99: FEAT_1: 31973d56 FEAT_2: Cart Balancer (Assessment)_3020 - Correlation: 0.9972032753730792
# 100: FEAT_1: b5053438 FEAT_2: d3268efa - Correlation: 0.999484815123522
# 101: FEAT_1: b5053438 FEAT_2: 28520915 - Correlation: 0.9990950947374551
# 102: FEAT_1: b5053438 FEAT_2: Cauldron Filler (Assessment)_3021 - Correlation: 0.999484815123522
# 103: FEAT_1: b5053438 FEAT_2: Cauldron Filler (Assessment)_2030 - Correlation: 0.9990950947374551
# 104: FEAT_1: b5053438 FEAT_2: Cauldron Filler (Assessment)_3121 - Correlation: 0.9999999999999998
# 105: FEAT_1: cc5087a3 FEAT_2: Crystals Rule_4010 - Correlation: 0.9999999999999998
# 106: FEAT_1: 4c2ec19f FEAT_2: Egg Dropper (Activity)_4025 - Correlation: 1.0
# 107: FEAT_1: 709b1251 FEAT_2: e3ff61fb - Correlation: 0.999572524598253
# 108: FEAT_1: 709b1251 FEAT_2: 7961e599 - Correlation: 0.9957962554268273
# 109: FEAT_1: 709b1251 FEAT_2: Dino Dive_3121 - Correlation: 1.0
# 110: FEAT_1: 709b1251 FEAT_2: Dino Dive_3021 - Correlation: 0.999572524598253
# 111: FEAT_1: 709b1251 FEAT_2: Dino Dive_2020 - Correlation: 0.9957962554268273
# 112: FEAT_1: 9d29771f FEAT_2: 3dfd4aa4 - Correlation: 0.996235496779867
# 113: FEAT_1: 9d29771f FEAT_2: c74f40cd - Correlation: 0.9999614251168224
# 114: FEAT_1: 9d29771f FEAT_2: 83c6c409 - Correlation: 0.9962369625175772
# 115: FEAT_1: 9d29771f FEAT_2: Mushroom Sorter (Assessment)_3121 - Correlation: 0.9999614251168224
# 116: FEAT_1: 9d29771f FEAT_2: Mushroom Sorter (Assessment)_3021 - Correlation: 1.0
# 117: FEAT_1: 9d29771f FEAT_2: Mushroom Sorter (Assessment)_2020 - Correlation: 0.996235496779867
# 118: FEAT_1: 9d29771f FEAT_2: Mushroom Sorter (Assessment)_2035 - Correlation: 0.9962369625175772
# 119: FEAT_1: 119b5b02 FEAT_2: Dino Dive_4080 - Correlation: 1.0
# 120: FEAT_1: abc5811c FEAT_2: Happy Camel_4010 - Correlation: 1.0
# 121: FEAT_1: 28f975ea FEAT_2: Air Show_4020 - Correlation: 0.9999999999999998
# 122: FEAT_1: 5f5b2617 FEAT_2: Bottle Filler (Activity)_4080 - Correlation: 1.0
# 123: FEAT_1: 1375ccb7 FEAT_2: bdf49a58 - Correlation: 0.9987067235730346
# 124: FEAT_1: 1375ccb7 FEAT_2: Bird Measurer (Assessment)_3110 - Correlation: 0.9987067235730346
# 125: FEAT_1: 1375ccb7 FEAT_2: Bird Measurer (Assessment)_3010 - Correlation: 1.0
# 126: FEAT_1: 93b353f2 FEAT_2: Chest Sorter (Assessment)_4100 - Correlation: 0.9999999999999998
# 127: FEAT_1: 85d1b0de FEAT_2: Chicken Balancer (Activity)_4090 - Correlation: 1.0
# 128: FEAT_1: 5c3d2b2f FEAT_2: Scrub-A-Dub_4020 - Correlation: 0.9999999999999999
# 129: FEAT_1: 45d01abe FEAT_2: 7525289a - Correlation: 0.998065773888081
# 130: FEAT_1: 45d01abe FEAT_2: Bird Measurer (Assessment)_3121 - Correlation: 0.998065773888081
# 131: FEAT_1: 45d01abe FEAT_2: Bird Measurer (Assessment)_3021 - Correlation: 1.0
# 132: FEAT_1: 6cf7d25c FEAT_2: 15f99afc - Correlation: 0.9993548901994774
# 133: FEAT_1: 6cf7d25c FEAT_2: Pan Balance_3110 - Correlation: 0.9993548901994774
# 134: FEAT_1: 6cf7d25c FEAT_2: Pan Balance_3010 - Correlation: 1.0
# 135: FEAT_1: 93edfe2e FEAT_2: Crystals Rule_4090 - Correlation: 0.9999999999999998
# 136: FEAT_1: 16667cc5 FEAT_2: Chicken Balancer (Activity)_4080 - Correlation: 0.9999999999999998
# 137: FEAT_1: 14de4c5d FEAT_2: Air Show_4100 - Correlation: 0.9999999999999999
# 138: FEAT_1: fd20ea40 FEAT_2: Leaf Leader_4010 - Correlation: 1.0
# 139: FEAT_1: e720d930 FEAT_2: 3323d7e9 - Correlation: 0.9998266553937638
# 140: FEAT_1: e720d930 FEAT_2: 7cf1bc53 - Correlation: 0.997505162422644
# 141: FEAT_1: e720d930 FEAT_2: 3ddc79c3 - Correlation: 0.999886028056185
# 142: FEAT_1: e720d930 FEAT_2: Crystals Rule_3121 - Correlation: 1.0
# 143: FEAT_1: e720d930 FEAT_2: Crystals Rule_3021 - Correlation: 0.999886028056185
# 144: FEAT_1: e720d930 FEAT_2: Crystals Rule_2020 - Correlation: 0.997505162422644
# 145: FEAT_1: e720d930 FEAT_2: Crystals Rule_2030 - Correlation: 0.9998266553937638
# 146: FEAT_1: 1996c610 FEAT_2: 4031 - Correlation: 1.0
# 147: FEAT_1: 1996c610 FEAT_2: Dino Drink_4031 - Correlation: 1.0
# 148: FEAT_1: 28a4eb9a FEAT_2: 9de5e594 - Correlation: 0.9997735286642271
# 149: FEAT_1: 28a4eb9a FEAT_2: Dino Dive_3120 - Correlation: 1.0
# 150: FEAT_1: 28a4eb9a FEAT_2: Dino Dive_3020 - Correlation: 0.9997735286642271
# 151: FEAT_1: 3bb91ced FEAT_2: Happy Camel_2081 - Correlation: 0.9999999999999999
# 152: FEAT_1: 763fc34e FEAT_2: e57dd7af - Correlation: 0.9970809705181877
# 153: FEAT_1: 763fc34e FEAT_2: Leaf Leader_3120 - Correlation: 0.9970809705181877
# 154: FEAT_1: 763fc34e FEAT_2: Leaf Leader_3020 - Correlation: 1.0
# 155: FEAT_1: 49ed92e9 FEAT_2: bd701df8 - Correlation: 0.9987858421173509
# 156: FEAT_1: 49ed92e9 FEAT_2: Watering Hole (Activity)_3010 - Correlation: 1.0
# 157: FEAT_1: 49ed92e9 FEAT_2: Watering Hole (Activity)_3110 - Correlation: 0.9987858421173509
# 158: FEAT_1: d2659ab4 FEAT_2: Air Show_2075 - Correlation: 0.9999999999999998
# 159: FEAT_1: 2b058fe3 FEAT_2: Cauldron Filler (Assessment)_2010 - Correlation: 1.0
# 160: FEAT_1: c952eb01 FEAT_2: Watering Hole (Activity)_4070 - Correlation: 1.0
# 161: FEAT_1: 87d743c1 FEAT_2: Dino Dive_4010 - Correlation: 0.9999999999999998
# 162: FEAT_1: 9554a50b FEAT_2: Cauldron Filler (Assessment)_4080 - Correlation: 1.0
# 163: FEAT_1: 06372577 FEAT_2: Air Show_2060 - Correlation: 1.0
# 164: FEAT_1: 1bb5fbdb FEAT_2: b2dba42b - Correlation: 0.9999142162856897
# 165: FEAT_1: 1bb5fbdb FEAT_2: Sandcastle Builder (Activity)_3010 - Correlation: 0.9999142162856897
# 166: FEAT_1: 1bb5fbdb FEAT_2: Sandcastle Builder (Activity)_3110 - Correlation: 1.0
# 167: FEAT_1: 37ee8496 FEAT_2: 30614231 - Correlation: 0.9967016361939669
# 168: FEAT_1: 37ee8496 FEAT_2: Cauldron Filler (Assessment)_4020 - Correlation: 0.9967016361939669
# 169: FEAT_1: 37ee8496 FEAT_2: Cauldron Filler (Assessment)_4030 - Correlation: 1.0
# 170: FEAT_1: 84538528 FEAT_2: Sandcastle Builder (Activity)_4020 - Correlation: 1.0
# 171: FEAT_1: 58a0de5c FEAT_2: 9b4001e4 - Correlation: 0.9999231952017581
# 172: FEAT_1: 58a0de5c FEAT_2: f5b8c21a - Correlation: 0.9957499978891368
# 173: FEAT_1: 58a0de5c FEAT_2: Air Show_3021 - Correlation: 0.9999231952017581
# 174: FEAT_1: 58a0de5c FEAT_2: Air Show_2030 - Correlation: 0.9957499978891368
# 175: FEAT_1: 58a0de5c FEAT_2: Air Show_3121 - Correlation: 1.0
# 176: FEAT_1: 884228c8 FEAT_2: Fireworks (Activity)_4070 - Correlation: 1.0
# 177: FEAT_1: dcaede90 FEAT_2: 73757a5e - Correlation: 0.99619219671537
# 178: FEAT_1: dcaede90 FEAT_2: 5a848010 - Correlation: 0.9972492617651455
# 179: FEAT_1: dcaede90 FEAT_2: 37c53127 - Correlation: 0.996119439722111
# 180: FEAT_1: dcaede90 FEAT_2: 2b9272f4 - Correlation: 0.9960368802444122
# 181: FEAT_1: dcaede90 FEAT_2: 2050 - Correlation: 0.996119439722111
# 182: FEAT_1: dcaede90 FEAT_2: 2040 - Correlation: 0.9999999999999999
# 183: FEAT_1: dcaede90 FEAT_2: Scrub-A-Dub_3021 - Correlation: 0.99619219671537
# 184: FEAT_1: dcaede90 FEAT_2: Scrub-A-Dub_2050 - Correlation: 0.996119439722111
# 185: FEAT_1: dcaede90 FEAT_2: Scrub-A-Dub_2080 - Correlation: 0.9972492617651455
# 186: FEAT_1: dcaede90 FEAT_2: Scrub-A-Dub_2040 - Correlation: 0.9999999999999999
# 187: FEAT_1: dcaede90 FEAT_2: Scrub-A-Dub_3121 - Correlation: 0.9960368802444122
# 188: FEAT_1: de26c3a6 FEAT_2: Flower Waterer (Activity)_4020 - Correlation: 0.9999999999999999
# 189: FEAT_1: f3cd5473 FEAT_2: Pan Balance_4070 - Correlation: 1.0
# 190: FEAT_1: 0d1da71f FEAT_2: Chow Time_3110 - Correlation: 1.0
# 191: FEAT_1: a8efe47b FEAT_2: Chest Sorter (Assessment)_4030 - Correlation: 1.0
# 192: FEAT_1: cb1178ad FEAT_2: Chest Sorter (Assessment)_4090 - Correlation: 0.9999999999999998
# 193: FEAT_1: 04df9b66 FEAT_2: 5290eab1 - Correlation: 0.999733638048424
# 194: FEAT_1: 04df9b66 FEAT_2: Cauldron Filler (Assessment)_3120 - Correlation: 0.999733638048424
# 195: FEAT_1: 04df9b66 FEAT_2: Cauldron Filler (Assessment)_3020 - Correlation: 1.0
# 196: FEAT_1: 56cd3b43 FEAT_2: bbfe0445 - Correlation: 0.9996708412822125
# 197: FEAT_1: 56cd3b43 FEAT_2: Flower Waterer (Activity)_3110 - Correlation: 0.9996708412822125
# 198: FEAT_1: 56cd3b43 FEAT_2: Flower Waterer (Activity)_3010 - Correlation: 1.0
# 199: FEAT_1: 77c76bc5 FEAT_2: Cauldron Filler (Assessment)_4090 - Correlation: 1.0
# 200: FEAT_1: a592d54e FEAT_2: 1c178d24 - Correlation: 0.9968474912288281
# 201: FEAT_1: a592d54e FEAT_2: cf7638f3 - Correlation: 0.9965233238739293
# 202: FEAT_1: a592d54e FEAT_2: 250513af - Correlation: 0.9968354909188485
# 203: FEAT_1: a592d54e FEAT_2: Pan Balance_3021 - Correlation: 0.9968354909188485
# 204: FEAT_1: a592d54e FEAT_2: Pan Balance_2030 - Correlation: 0.9968474912288281
# 205: FEAT_1: a592d54e FEAT_2: Pan Balance_2020 - Correlation: 1.0
# 206: FEAT_1: a592d54e FEAT_2: Pan Balance_3121 - Correlation: 0.9965233238739293
# 207: FEAT_1: 84b0e0c8 FEAT_2: ea321fb1 - Correlation: 0.9992626433101821
# 208: FEAT_1: 84b0e0c8 FEAT_2: Chicken Balancer (Activity)_3110 - Correlation: 0.9999999999999999
# 209: FEAT_1: 84b0e0c8 FEAT_2: Chicken Balancer (Activity)_3010 - Correlation: 0.9992626433101821
# 210: FEAT_1: 3a4be871 FEAT_2: Flower Waterer (Activity)_4080 - Correlation: 1.0
# 211: FEAT_1: 17113b36 FEAT_2: e37a2b78 - Correlation: 0.9981774724155311
# 212: FEAT_1: 17113b36 FEAT_2: ad2fc29c - Correlation: 0.9988381596234415
# 213: FEAT_1: 17113b36 FEAT_2: Bird Measurer (Assessment)_4110 - Correlation: 1.0
# 214: FEAT_1: 17113b36 FEAT_2: Bird Measurer (Assessment)_3020 - Correlation: 0.9988381596234415
# 215: FEAT_1: 17113b36 FEAT_2: Bird Measurer (Assessment)_3120 - Correlation: 0.9981774724155311
# 216: FEAT_1: c7128948 FEAT_2: Mushroom Sorter (Assessment)_4040 - Correlation: 0.9999999999999999
# 217: FEAT_1: 9ce586dd FEAT_2: Chest Sorter (Assessment)_4035 - Correlation: 0.9999999999999999
# 218: FEAT_1: 02a42007 FEAT_2: Fireworks (Activity)_4030 - Correlation: 1.0
# 219: FEAT_1: 8f094001 FEAT_2: 1beb320a - Correlation: 0.9978121806652563
# 220: FEAT_1: 8f094001 FEAT_2: 3bb91dda - Correlation: 0.9956943360781472
# 221: FEAT_1: 8f094001 FEAT_2: c54cf6c5 - Correlation: 0.9955291081861417
# 222: FEAT_1: 8f094001 FEAT_2: Bubble Bath_4020 - Correlation: 0.9956943360781472
# 223: FEAT_1: 8f094001 FEAT_2: Bubble Bath_2020 - Correlation: 0.9978121806652563
# 224: FEAT_1: 8f094001 FEAT_2: Bubble Bath_2025 - Correlation: 0.9955291081861417
# 225: FEAT_1: 8f094001 FEAT_2: Bubble Bath_4045 - Correlation: 1.0
# 226: FEAT_1: 828e68f9 FEAT_2: Cart Balancer (Assessment)_3110 - Correlation: 0.9999999999999998
# 227: FEAT_1: f93fc684 FEAT_2: Chow Time_4010 - Correlation: 1.0
# 228: FEAT_1: 6f4bd64e FEAT_2: Air Show_4090 - Correlation: 0.9999999999999998
# 229: FEAT_1: e7561dd2 FEAT_2: Pan Balance_4025 - Correlation: 1.0
# 230: FEAT_1: 44cb4907 FEAT_2: 8b757ab8 - Correlation: 0.9998293038134246
# 231: FEAT_1: 44cb4907 FEAT_2: Crystals Rule_3120 - Correlation: 0.9998293038134246
# 232: FEAT_1: 44cb4907 FEAT_2: Crystals Rule_3020 - Correlation: 1.0
# 233: FEAT_1: 3d0b9317 FEAT_2: Chest Sorter (Assessment)_4040 - Correlation: 0.9999999999999999
# 234: FEAT_1: 17ca3959 FEAT_2: Crystals Rule_2010 - Correlation: 1.0
# 235: FEAT_1: a29c5338 FEAT_2: 7f0836bf - Correlation: 0.9982956022481702
# 236: FEAT_1: a29c5338 FEAT_2: Dino Drink_3010 - Correlation: 1.0
# 237: FEAT_1: a29c5338 FEAT_2: Dino Drink_3110 - Correlation: 0.9982956022481702
# 238: FEAT_1: 92687c59 FEAT_2: Scrub-A-Dub_4090 - Correlation: 0.9999999999999999
# 239: FEAT_1: 363c86c9 FEAT_2: Bug Measurer (Activity)_4035 - Correlation: 0.9999999999999998
# 240: FEAT_1: b74258a0 FEAT_2: b2e5b0f1 - Correlation: 0.9998551711075218
# 241: FEAT_1: b74258a0 FEAT_2: ecaab346 - Correlation: 0.9999999999999999
# 242: FEAT_1: b74258a0 FEAT_2: Cart Balancer (Assessment)_3121 - Correlation: 0.9999999999999999
# 243: FEAT_1: b74258a0 FEAT_2: Cart Balancer (Assessment)_2010 - Correlation: 0.9998551711075218
# 244: FEAT_1: b74258a0 FEAT_2: Cart Balancer (Assessment)_2030 - Correlation: 0.9999999999999999
# 245: FEAT_1: 00c73085 FEAT_2: Dino Dive_2030 - Correlation: 1.0
# 246: FEAT_1: 3babcb9b FEAT_2: 5154fc30 - Correlation: 0.9999789227413821
# 247: FEAT_1: 3babcb9b FEAT_2: 86c924c4 - Correlation: 0.9988495349670002
# 248: FEAT_1: 3babcb9b FEAT_2: Crystals Rule_3010 - Correlation: 0.9999789227413821
# 249: FEAT_1: 3babcb9b FEAT_2: Crystals Rule_4020 - Correlation: 0.9988495349670002
# 250: FEAT_1: 3babcb9b FEAT_2: Crystals Rule_3110 - Correlation: 1.0
# 251: FEAT_1: a52b92d5 FEAT_2: a1e4395d - Correlation: 0.9984314647527737
# 252: FEAT_1: a52b92d5 FEAT_2: Mushroom Sorter (Assessment)_3110 - Correlation: 0.9999999999999998
# 253: FEAT_1: a52b92d5 FEAT_2: Mushroom Sorter (Assessment)_3010 - Correlation: 0.9984314647527737
# 254: FEAT_1: d88ca108 FEAT_2: Air Show_2070 - Correlation: 1.0
# 255: FEAT_1: f6947f54 FEAT_2: Bird Measurer (Assessment)_2030 - Correlation: 1.0
# 256: FEAT_1: c1cac9a2 FEAT_2: Scrub-A-Dub_2081 - Correlation: 0.9999999999999999
# 257: FEAT_1: daac11b0 FEAT_2: 1f19558b - Correlation: 0.9990593937500083
# 258: FEAT_1: daac11b0 FEAT_2: ca11f653 - Correlation: 0.9994973170856544
# 259: FEAT_1: daac11b0 FEAT_2: All Star Sorting_3121 - Correlation: 0.9990593937500083
# 260: FEAT_1: daac11b0 FEAT_2: All Star Sorting_3021 - Correlation: 0.9999999999999998
# 261: FEAT_1: daac11b0 FEAT_2: All Star Sorting_2030 - Correlation: 0.9994973170856544
# 262: FEAT_1: e5734469 FEAT_2: 89aace00 - Correlation: 0.9998056383036865
# 263: FEAT_1: e5734469 FEAT_2: Dino Drink_3020 - Correlation: 1.0
# 264: FEAT_1: e5734469 FEAT_2: Dino Drink_3120 - Correlation: 0.9998056383036865
# 265: FEAT_1: 499edb7c FEAT_2: Chicken Balancer (Activity)_4020 - Correlation: 1.0
# 266: FEAT_1: 7ec0c298 FEAT_2: Chow Time_3010 - Correlation: 0.9999999999999999
# 267: FEAT_1: 3dcdda7f FEAT_2: 3ccd3f02 - Correlation: 0.9966343534066285
# 268: FEAT_1: 3dcdda7f FEAT_2: Chest Sorter (Assessment)_3010 - Correlation: 1.0
# 269: FEAT_1: 3dcdda7f FEAT_2: Chest Sorter (Assessment)_3110 - Correlation: 0.9966343534066285
# 270: FEAT_1: 7dfe6d8a FEAT_2: Leaf Leader_4070 - Correlation: 1.0
# 271: FEAT_1: ad148f58 FEAT_2: 85de926c - Correlation: 0.999999528735118
# 272: FEAT_1: ad148f58 FEAT_2: 4230 - Correlation: 1.0
# 273: FEAT_1: ad148f58 FEAT_2: 4235 - Correlation: 0.999999528735118
# 274: FEAT_1: ad148f58 FEAT_2: Bubble Bath_4235 - Correlation: 0.999999528735118
# 275: FEAT_1: ad148f58 FEAT_2: Bubble Bath_4230 - Correlation: 1.0
# 276: FEAT_1: 9ee1c98c FEAT_2: Sandcastle Builder (Activity)_4021 - Correlation: 1.0
# 277: FEAT_1: 363d3849 FEAT_2: 9e4c8c7b - Correlation: 0.9991279615935746
# 278: FEAT_1: 363d3849 FEAT_2: All Star Sorting_3110 - Correlation: 0.9991279615935746
# 279: FEAT_1: 363d3849 FEAT_2: All Star Sorting_3010 - Correlation: 1.0
# 280: FEAT_1: 598f4598 FEAT_2: Flower Waterer (Activity)_4025 - Correlation: 0.9999999999999998
# 281: FEAT_1: a44b10dc FEAT_2: Flower Waterer (Activity)_4070 - Correlation: 1.0
# 282: FEAT_1: 4d6737eb FEAT_2: Dino Drink_2070 - Correlation: 1.0
# 283: FEAT_1: 46cd75b4 FEAT_2: Chicken Balancer (Activity)_4022 - Correlation: 0.9999999999999999
# 284: FEAT_1: 30df3273 FEAT_2: Sandcastle Builder (Activity)_4080 - Correlation: 1.0
# 285: FEAT_1: 2dc29e21 FEAT_2: All Star Sorting_4020 - Correlation: 0.9999999999999999
# 286: FEAT_1: bb3e370b FEAT_2: Bottle Filler (Activity)_4030 - Correlation: 1.0
# 287: FEAT_1: d3640339 FEAT_2: Dino Dive_4090 - Correlation: 1.0
# 288: FEAT_1: 2ec694de FEAT_2: Bug Measurer (Activity)_4080 - Correlation: 0.9999999999999998
# 289: FEAT_1: cfbd47c8 FEAT_2: Chow Time_4030 - Correlation: 0.9999999999999999
# 290: FEAT_1: a8876db3 FEAT_2: Cart Balancer (Assessment)_3021 - Correlation: 0.9999999999999999
# 291: FEAT_1: 74e5f8a7 FEAT_2: Dino Drink_4020 - Correlation: 0.9999999999999999
# 292: FEAT_1: 5e3ea25a FEAT_2: Crystals Rule_4070 - Correlation: 1.0
# 293: FEAT_1: f806dc10 FEAT_2: Dino Drink_2020 - Correlation: 0.9999999999999999
# 294: FEAT_1: 6f8106d9 FEAT_2: Dino Drink_4090 - Correlation: 1.0
# 295: FEAT_1: 804ee27f FEAT_2: Pan Balance_4020 - Correlation: 1.0
# 296: FEAT_1: 0086365d FEAT_2: Pan Balance_4010 - Correlation: 1.0
# 297: FEAT_1: 2a444e03 FEAT_2: Pan Balance_4030 - Correlation: 0.9999999999999999
# 298: FEAT_1: c189aaf2 FEAT_2: Happy Camel_2083 - Correlation: 1.0
# 299: FEAT_1: a76029ee FEAT_2: Bird Measurer (Assessment)_4040 - Correlation: 1.0
# 300: FEAT_1: 5f0eb72c FEAT_2: Mushroom Sorter (Assessment)_4020 - Correlation: 0.9999999999999998
# 301: FEAT_1: 8d84fa81 FEAT_2: Bubble Bath_4010 - Correlation: 1.0
# 302: FEAT_1: 08ff79ad FEAT_2: Egg Dropper (Activity)_4090 - Correlation: 0.9999999999999999
# 303: FEAT_1: 01ca3a3c FEAT_2: Leaf Leader_4080 - Correlation: 0.9999999999999998
# 304: FEAT_1: 3d63345e FEAT_2: Cart Balancer (Assessment)_4035 - Correlation: 1.0
# 305: FEAT_1: beb0a7b9 FEAT_2: b88f38da - Correlation: 0.9998524462332803
# 306: FEAT_1: beb0a7b9 FEAT_2: Fireworks (Activity)_3010 - Correlation: 1.0
# 307: FEAT_1: beb0a7b9 FEAT_2: Fireworks (Activity)_3110 - Correlation: 0.9998524462332803
# 308: FEAT_1: f54238ee FEAT_2: Fireworks (Activity)_4090 - Correlation: 1.0
# 309: FEAT_1: 7040c096 FEAT_2: Scrub-A-Dub_4010 - Correlation: 1.0
# 310: FEAT_1: 53c6e11a FEAT_2: Leaf Leader_2075 - Correlation: 1.0
# 311: FEAT_1: ecc6157f FEAT_2: Cart Balancer (Assessment)_4080 - Correlation: 1.0
# 312: FEAT_1: f32856e4 FEAT_2: Leaf Leader_2020 - Correlation: 1.0
# 313: FEAT_1: 0d18d96c FEAT_2: Mushroom Sorter (Assessment)_4035 - Correlation: 0.9999999999999999
# 314: FEAT_1: c58186bf FEAT_2: Sandcastle Builder (Activity)_4035 - Correlation: 1.0
# 315: FEAT_1: 90efca10 FEAT_2: Bottle Filler (Activity)_4020 - Correlation: 1.0
# 316: FEAT_1: f71c4741 FEAT_2: f7e47413 - Correlation: 0.9999435624173822
# 317: FEAT_1: f71c4741 FEAT_2: Scrub-A-Dub_3010 - Correlation: 1.0
# 318: FEAT_1: f71c4741 FEAT_2: Scrub-A-Dub_3110 - Correlation: 0.9999435624173822
# 319: FEAT_1: d02b7a8e FEAT_2: All Star Sorting_4035 - Correlation: 0.9999999999999998
# 320: FEAT_1: 5be391b5 FEAT_2: Dino Drink_4010 - Correlation: 0.9999999999999999
# 321: FEAT_1: d45ed6a1 FEAT_2: b120f2ac - Correlation: 0.9978351644271254
# 322: FEAT_1: d45ed6a1 FEAT_2: c277e121 - Correlation: 0.9978343382666868
# 323: FEAT_1: d45ed6a1 FEAT_2: All Star Sorting_3020 - Correlation: 0.9978343382666868
# 324: FEAT_1: d45ed6a1 FEAT_2: All Star Sorting_3120 - Correlation: 0.9999999999999998
# 325: FEAT_1: d45ed6a1 FEAT_2: All Star Sorting_2025 - Correlation: 0.9978351644271254
# 326: FEAT_1: 99abe2bb FEAT_2: Bubble Bath_2080 - Correlation: 1.0
# 327: FEAT_1: 3bf1cf26 FEAT_2: 1af8be29 - Correlation: 0.9998785285037075
# 328: FEAT_1: 3bf1cf26 FEAT_2: Happy Camel_3020 - Correlation: 0.9998785285037075
# 329: FEAT_1: 3bf1cf26 FEAT_2: Happy Camel_3120 - Correlation: 1.0
# 330: FEAT_1: 3edf6747 FEAT_2: Cauldron Filler (Assessment)_4035 - Correlation: 1.0
# 331: FEAT_1: d2e9262e FEAT_2: 2fb91ec1 - Correlation: 0.9990679827878484
# 332: FEAT_1: d2e9262e FEAT_2: Watering Hole (Activity)_4020 - Correlation: 1.0
# 333: FEAT_1: d2e9262e FEAT_2: Watering Hole (Activity)_4025 - Correlation: 0.9990679827878484
# 334: FEAT_1: e4d32835 FEAT_2: Pan Balance_4080 - Correlation: 1.0
# 335: FEAT_1: a5be6304 FEAT_2: 6c930e6e - Correlation: 0.9963106255294892
# 336: FEAT_1: a5be6304 FEAT_2: Mushroom Sorter (Assessment)_2010 - Correlation: 1.0
# 337: FEAT_1: a5be6304 FEAT_2: Mushroom Sorter (Assessment)_2030 - Correlation: 0.9963106255294892
# 338: FEAT_1: 562cec5f FEAT_2: Chest Sorter (Assessment)_4025 - Correlation: 0.9999999999999999
# 339: FEAT_1: 022b4259 FEAT_2: Bug Measurer (Activity)_4025 - Correlation: 1.0
# 340: FEAT_1: 1325467d FEAT_2: Sandcastle Builder (Activity)_4070 - Correlation: 1.0
# 341: FEAT_1: c51d8688 FEAT_2: 907a054b - Correlation: 0.9999653418541941
# 342: FEAT_1: c51d8688 FEAT_2: Pan Balance_3120 - Correlation: 1.0
# 343: FEAT_1: c51d8688 FEAT_2: Pan Balance_3020 - Correlation: 0.9999653418541941
# 344: FEAT_1: 3393b68b FEAT_2: Bird Measurer (Assessment)_2010 - Correlation: 1.0
# 345: FEAT_1: 2dcad279 FEAT_2: 923afab1 - Correlation: 0.9997915642968869
# 346: FEAT_1: 2dcad279 FEAT_2: Cauldron Filler (Assessment)_3010 - Correlation: 0.9997915642968869
# 347: FEAT_1: 2dcad279 FEAT_2: Cauldron Filler (Assessment)_3110 - Correlation: 1.0
# 348: FEAT_1: d122731b FEAT_2: Cart Balancer (Assessment)_4100 - Correlation: 1.0
# 349: FEAT_1: 4e5fc6f5 FEAT_2: Cart Balancer (Assessment)_4090 - Correlation: 0.9999999999999999
# 350: FEAT_1: 36fa3ebe FEAT_2: c7fe2a55 - Correlation: 0.99978862834929
# 351: FEAT_1: 36fa3ebe FEAT_2: a8a78786 - Correlation: 0.9976470826450272
# 352: FEAT_1: 36fa3ebe FEAT_2: Happy Camel_3021 - Correlation: 0.99978862834929
# 353: FEAT_1: 36fa3ebe FEAT_2: Happy Camel_3121 - Correlation: 0.9976470826450272
# 354: FEAT_1: 36fa3ebe FEAT_2: Happy Camel_2030 - Correlation: 1.0
# 355: FEAT_1: 47efca07 FEAT_2: Bottle Filler (Activity)_4090 - Correlation: 0.9999999999999999
# 356: FEAT_1: df4940d3 FEAT_2: 67439901 - Correlation: 0.9999245104350836
# 357: FEAT_1: df4940d3 FEAT_2: Bottle Filler (Activity)_3010 - Correlation: 0.9999245104350836
# 358: FEAT_1: df4940d3 FEAT_2: Bottle Filler (Activity)_3110 - Correlation: 1.0
# 359: FEAT_1: a2df0760 FEAT_2: Happy Camel_4035 - Correlation: 0.9999999999999999
# 360: FEAT_1: e694a35b FEAT_2: Fireworks (Activity)_4020 - Correlation: 1.0
# 361: FEAT_1: ec138c1c FEAT_2: Bird Measurer (Assessment)_2020 - Correlation: 1.0
# 362: FEAT_1: 90ea0bac FEAT_2: 5859dfb6 - Correlation: 0.998143199779257
# 363: FEAT_1: 90ea0bac FEAT_2: Bubble Bath_3120 - Correlation: 0.998143199779257
# 364: FEAT_1: 90ea0bac FEAT_2: Bubble Bath_3020 - Correlation: 1.0
# 365: FEAT_1: bcceccc6 FEAT_2: Air Show_4070 - Correlation: 1.0
# 366: FEAT_1: 792530f8 FEAT_2: Dino Drink_4030 - Correlation: 1.0
# 367: FEAT_1: c2baf0bd FEAT_2: Happy Camel_2020 - Correlation: 1.0
# 368: FEAT_1: 2230fab4 FEAT_2: 0330ab6a - Correlation: 0.9998679618458088
# 369: FEAT_1: 2230fab4 FEAT_2: Chow Time_3020 - Correlation: 0.9998679618458088
# 370: FEAT_1: 2230fab4 FEAT_2: Chow Time_3120 - Correlation: 1.0
# 371: FEAT_1: a16a373e FEAT_2: Bird Measurer (Assessment)_4070 - Correlation: 0.9999999999999998
# 372: FEAT_1: 7d5c30a2 FEAT_2: Dino Dive_2060 - Correlation: 1.0
# 373: FEAT_1: 05ad839b FEAT_2: Happy Camel_4090 - Correlation: 1.0
# 374: FEAT_1: c6971acf FEAT_2: Dino Drink_2060 - Correlation: 1.0
# 375: FEAT_1: e04fb33d FEAT_2: 7423acbc - Correlation: 0.9996366277965577
# 376: FEAT_1: e04fb33d FEAT_2: Air Show_3020 - Correlation: 0.9996366277965577
# 377: FEAT_1: e04fb33d FEAT_2: Air Show_3120 - Correlation: 1.0
# 378: FEAT_1: 08fd73f3 FEAT_2: 26fd2d99 - Correlation: 0.999535245792697
# 379: FEAT_1: 08fd73f3 FEAT_2: Scrub-A-Dub_2030 - Correlation: 0.9999999999999998
# 380: FEAT_1: 08fd73f3 FEAT_2: Scrub-A-Dub_2020 - Correlation: 0.999535245792697
# 381: FEAT_1: 0413e89d FEAT_2: 15eb4a7d - Correlation: 0.9996985020551941
# 382: FEAT_1: 0413e89d FEAT_2: Bubble Bath_3010 - Correlation: 1.0
# 383: FEAT_1: 0413e89d FEAT_2: Bubble Bath_3110 - Correlation: 0.9996985020551941
# 384: FEAT_1: 16dffff1 FEAT_2: 77ead60d - Correlation: 0.9984261276989953
# 385: FEAT_1: 16dffff1 FEAT_2: 4d911100 - Correlation: 0.9985584138798833
# 386: FEAT_1: 16dffff1 FEAT_2: Dino Drink_3021 - Correlation: 0.9984261276989953
# 387: FEAT_1: 16dffff1 FEAT_2: Dino Drink_3121 - Correlation: 0.9985584138798833
# 388: FEAT_1: 16dffff1 FEAT_2: Dino Drink_2030 - Correlation: 1.0
# 389: FEAT_1: 8d7e386c FEAT_2: 69fdac0a - Correlation: 0.9996234088283591
# 390: FEAT_1: 8d7e386c FEAT_2: Happy Camel_3010 - Correlation: 1.0
# 391: FEAT_1: 8d7e386c FEAT_2: Happy Camel_3110 - Correlation: 0.9996234088283591
# 392: FEAT_1: ecc36b7f FEAT_2: Bubble Bath_4095 - Correlation: 1.0
# 393: FEAT_1: 6bf9e3e1 FEAT_2: Happy Camel_4040 - Correlation: 1.0
# 394: FEAT_1: 5348fd84 FEAT_2: Cauldron Filler (Assessment)_4040 - Correlation: 0.9999999999999999
# 395: FEAT_1: bd612267 FEAT_2: Chest Sorter (Assessment)_4070 - Correlation: 0.9999999999999999
# 396: FEAT_1: 0a08139c FEAT_2: 71fe8f75 - Correlation: 0.9999816561371594
# 397: FEAT_1: 0a08139c FEAT_2: Bug Measurer (Activity)_3010 - Correlation: 0.9999999999999999
# 398: FEAT_1: 0a08139c FEAT_2: Bug Measurer (Activity)_3110 - Correlation: 0.9999816561371594
# 399: FEAT_1: 28ed704e FEAT_2: Mushroom Sorter (Assessment)_4025 - Correlation: 1.0
# 400: FEAT_1: d88e8f25 FEAT_2: ac92046e - Correlation: 0.9999825361383037
# 401: FEAT_1: d88e8f25 FEAT_2: Scrub-A-Dub_3020 - Correlation: 1.0
# 402: FEAT_1: d88e8f25 FEAT_2: Scrub-A-Dub_3120 - Correlation: 0.9999825361383037
# 403: FEAT_1: 7da34a02 FEAT_2: Mushroom Sorter (Assessment)_4070 - Correlation: 1.0
# 404: FEAT_1: 392e14df FEAT_2: Cauldron Filler (Assessment)_4100 - Correlation: 0.9999999999999998
# 405: FEAT_1: 37db1c2f FEAT_2: Happy Camel_4045 - Correlation: 1.0
# 406: FEAT_1: a6d66e51 FEAT_2: 71e712d8 - Correlation: 0.9992150527966184
# 407: FEAT_1: a6d66e51 FEAT_2: 5000 - Correlation: 1.0
# 408: FEAT_1: a6d66e51 FEAT_2: 5010 - Correlation: 0.9992150527966184
# 409: FEAT_1: a6d66e51 FEAT_2: Watering Hole (Activity)_5000 - Correlation: 1.0
# 410: FEAT_1: a6d66e51 FEAT_2: Watering Hole (Activity)_5010 - Correlation: 0.9992150527966184
# 411: FEAT_1: 15a43e5b FEAT_2: Bottle Filler (Activity)_4070 - Correlation: 1.0
# 412: FEAT_1: a5e9da97 FEAT_2: Pan Balance_4100 - Correlation: 1.0
# 413: FEAT_1: 262136f4 FEAT_2: Leaf Leader_4020 - Correlation: 1.0
# 414: FEAT_1: 4074bac2 FEAT_2: Pan Balance_2010 - Correlation: 1.0
# 415: FEAT_1: 19967db1 FEAT_2: Chow Time_4090 - Correlation: 1.0
# 416: FEAT_1: 611485c5 FEAT_2: Fireworks (Activity)_4080 - Correlation: 0.9999999999999999
# 417: FEAT_1: b1d5101d FEAT_2: All Star Sorting_4095 - Correlation: 1.0
# 418: FEAT_1: bc8f2793 FEAT_2: Pan Balance_4035 - Correlation: 1.0
# 419: FEAT_1: b80e5e84 FEAT_2: 7ab78247 - Correlation: 0.9997119008494356
# 420: FEAT_1: b80e5e84 FEAT_2: Egg Dropper (Activity)_3010 - Correlation: 0.9997119008494356
# 421: FEAT_1: b80e5e84 FEAT_2: Egg Dropper (Activity)_3110 - Correlation: 0.9999999999999998
# 422: FEAT_1: 532a2afb FEAT_2: Cauldron Filler (Assessment)_2020 - Correlation: 1.0
# 423: FEAT_1: 33505eae FEAT_2: 2a512369 - Correlation: 0.9994595194498185
# 424: FEAT_1: 33505eae FEAT_2: Leaf Leader_3110 - Correlation: 0.9994595194498185
# 425: FEAT_1: 33505eae FEAT_2: Leaf Leader_3010 - Correlation: 0.9999999999999998
# 426: FEAT_1: 070a5291 FEAT_2: Bird Measurer (Assessment)_4100 - Correlation: 1.0
# 427: FEAT_1: 587b5989 FEAT_2: All Star Sorting_4070 - Correlation: 1.0
# 428: FEAT_1: a7640a16 FEAT_2: Happy Camel_4070 - Correlation: 0.9999999999999999
# 429: FEAT_1: 565a3990 FEAT_2: Bug Measurer (Activity)_4070 - Correlation: 1.0
# 430: FEAT_1: 7372e1a5 FEAT_2: Chow Time_4070 - Correlation: 1.0
# 431: FEAT_1: 5e812b27 FEAT_2: Sandcastle Builder (Activity)_4030 - Correlation: 1.0
# 432: FEAT_1: 4ef8cdd3 FEAT_2: Chow Time_4020 - Correlation: 0.9999999999999999
# 433: FEAT_1: ea296733 FEAT_2: df4fe8b6 - Correlation: 0.9970637804060843
# 434: FEAT_1: ea296733 FEAT_2: Chest Sorter (Assessment)_3120 - Correlation: 0.9970637804060843
# 435: FEAT_1: ea296733 FEAT_2: Chest Sorter (Assessment)_3020 - Correlation: 1.0
# 436: FEAT_1: 3afde5dd FEAT_2: b012cd7f - Correlation: 0.9999721775937498
# 437: FEAT_1: 3afde5dd FEAT_2: e5c9df6f - Correlation: 0.9991114327772155
# 438: FEAT_1: 3afde5dd FEAT_2: Leaf Leader_3021 - Correlation: 1.0
# 439: FEAT_1: 3afde5dd FEAT_2: Leaf Leader_2030 - Correlation: 0.9999721775937498
# 440: FEAT_1: 3afde5dd FEAT_2: Leaf Leader_3121 - Correlation: 0.9991114327772155
# 441: FEAT_1: 29a42aea FEAT_2: Bubble Bath_4080 - Correlation: 0.9999999999999998
# 442: FEAT_1: 857f21c0 FEAT_2: Bubble Bath_4040 - Correlation: 0.9999999999999999
# 443: FEAT_1: d38c2fd7 FEAT_2: Bird Measurer (Assessment)_4035 - Correlation: 1.0
# 444: FEAT_1: 5c2f29ca FEAT_2: Cart Balancer (Assessment)_4020 - Correlation: 1.0
# 445: FEAT_1: 6c517a88 FEAT_2: Dino Drink_4070 - Correlation: 0.9999999999999998
# 446: FEAT_1: 9e6b7fb5 FEAT_2: Chow Time_4095 - Correlation: 1.0
# 447: FEAT_1: d3f1e122 FEAT_2: Bottle Filler (Activity)_4035 - Correlation: 1.0
# 448: FEAT_1: 1575e76c FEAT_2: Air Show_2020 - Correlation: 0.9999999999999999
# 449: FEAT_1: 2c4e6db0 FEAT_2: All Star Sorting_2020 - Correlation: 0.9999999999999998
# 450: FEAT_1: 160654fd FEAT_2: 88d4a5be - Correlation: 0.9982896439450233
# 451: FEAT_1: 160654fd FEAT_2: Mushroom Sorter (Assessment)_3020 - Correlation: 1.0
# 452: FEAT_1: 160654fd FEAT_2: Mushroom Sorter (Assessment)_3120 - Correlation: 0.9982896439450233
# 453: FEAT_1: fbaf3456 FEAT_2: Mushroom Sorter (Assessment)_4030 - Correlation: 1.0
# 454: FEAT_1: eb2c19cd FEAT_2: Mushroom Sorter (Assessment)_4090 - Correlation: 0.9999999999999999
# 455: FEAT_1: 86ba578b FEAT_2: Leaf Leader_2070 - Correlation: 0.9999999999999998
# 456: FEAT_1: 29f54413 FEAT_2: Leaf Leader_2060 - Correlation: 0.9999999999999998
# 457: FEAT_1: bfc77bd6 FEAT_2: Chest Sorter (Assessment)_4080 - Correlation: 1.0
# 458: FEAT_1: 4a4c3d21 FEAT_2: Bird Measurer (Assessment)_4025 - Correlation: 0.9999999999999999
# 459: FEAT_1: 26a5a3dd FEAT_2: All Star Sorting_4080 - Correlation: 1.0
# 460: FEAT_1: 13f56524 FEAT_2: Mushroom Sorter (Assessment)_4080 - Correlation: 1.0
# 461: FEAT_1: 832735e1 FEAT_2: ab3136ba - Correlation: 0.9998924110297333
# 462: FEAT_1: 832735e1 FEAT_2: Dino Dive_3110 - Correlation: 0.9998924110297333
# 463: FEAT_1: 832735e1 FEAT_2: Dino Dive_3010 - Correlation: 1.0
# 464: FEAT_1: 4bb2f698 FEAT_2: Chicken Balancer (Activity)_4070 - Correlation: 0.9999999999999998
# 465: FEAT_1: d185d3ea FEAT_2: Chow Time_4035 - Correlation: 1.0
# 466: FEAT_1: a1192f43 FEAT_2: 4050 - Correlation: 0.9999999999999999
# 467: FEAT_1: a1192f43 FEAT_2: Crystals Rule_4050 - Correlation: 0.9999999999999999
# 468: FEAT_1: 8fee50e2 FEAT_2: Bird Measurer (Assessment)_4020 - Correlation: 1.0
# 469: FEAT_1: 5d042115 FEAT_2: Flower Waterer (Activity)_4030 - Correlation: 1.0
# 470: FEAT_1: 76babcde FEAT_2: Dino Dive_4070 - Correlation: 1.0
# 471: FEAT_1: 56bcd38d FEAT_2: Chicken Balancer (Activity)_4030 - Correlation: 1.0
# 472: FEAT_1: ab4ec3a4 FEAT_2: Dino Drink_4080 - Correlation: 0.9999999999999999
# 473: FEAT_1: 1b54d27f FEAT_2: Watering Hole (Activity)_2010 - Correlation: 1.0
# 474: FEAT_1: 731c0cbe FEAT_2: Bird Measurer (Assessment)_4090 - Correlation: 1.0
# 475: FEAT_1: 8d748b58 FEAT_2: Bug Measurer (Activity)_4090 - Correlation: 0.9999999999999998
# 476: FEAT_1: 3d8c61b0 FEAT_2: Happy Camel_4030 - Correlation: 0.9999999999999999
# 477: FEAT_1: 6f445b57 FEAT_2: Chow Time_4080 - Correlation: 0.9999999999999998
# 478: FEAT_1: 47f43a44 FEAT_2: Flower Waterer (Activity)_4090 - Correlation: 1.0
# 479: FEAT_1: 0ce40006 FEAT_2: Happy Camel_4080 - Correlation: 0.9999999999999999
# 480: FEAT_1: a0faea5d FEAT_2: Bubble Bath_4070 - Correlation: 1.0
# 481: FEAT_1: 4a09ace1 FEAT_2: Scrub-A-Dub_2083 - Correlation: 1.0
# 482: FEAT_1: d06f75b5 FEAT_2: 895865f3 - Correlation: 0.9991823134578932
# 483: FEAT_1: d06f75b5 FEAT_2: Bubble Bath_2030 - Correlation: 0.9991823134578932
# 484: FEAT_1: d06f75b5 FEAT_2: Bubble Bath_2035 - Correlation: 1.0
# 485: FEAT_1: f28c589a FEAT_2: a1bbe385 - Correlation: 0.9999188133478474
# 486: FEAT_1: f28c589a FEAT_2: Air Show_3010 - Correlation: 0.9999999999999998
# 487: FEAT_1: f28c589a FEAT_2: Air Show_3110 - Correlation: 0.9999188133478474
# 488: FEAT_1: 6f4adc4b FEAT_2: 55115cbd - Correlation: 0.9997794156940226
# 489: FEAT_1: 6f4adc4b FEAT_2: Bubble Bath_3121 - Correlation: 0.9997794156940226
# 490: FEAT_1: 6f4adc4b FEAT_2: Bubble Bath_3021 - Correlation: 1.0
# 491: FEAT_1: 46b50ba8 FEAT_2: Happy Camel_4095 - Correlation: 1.0
# 492: FEAT_1: b7530680 FEAT_2: e9c52111 - Correlation: 0.9985636786792089
# 493: FEAT_1: b7530680 FEAT_2: Bottle Filler (Activity)_2030 - Correlation: 0.9985636786792089
# 494: FEAT_1: b7530680 FEAT_2: Bottle Filler (Activity)_2020 - Correlation: 1.0
# 495: FEAT_1: e080a381 FEAT_2: Pan Balance_4090 - Correlation: 1.0
# 496: FEAT_1: e79f3763 FEAT_2: Bug Measurer (Activity)_4030 - Correlation: 1.0
# 497: FEAT_1: 6077cc36 FEAT_2: Bird Measurer (Assessment)_4080 - Correlation: 1.0
# 498: FEAT_1: cdd22e43 FEAT_2: Chicken Balancer (Activity)_4035 - Correlation: 0.9999999999999999
# 499: FEAT_1: d51b1749 FEAT_2: Happy Camel_2080 - Correlation: 1.0
# 500: FEAT_1: 1cc7cfca FEAT_2: All Star Sorting_4030 - Correlation: 0.9999999999999999
# 501: FEAT_1: c0415e5c FEAT_2: Dino Dive_4020 - Correlation: 0.9999999999999999
# 502: FEAT_1: cf82af56 FEAT_2: Scrub-A-Dub_4070 - Correlation: 1.0
# 503: FEAT_1: 9d4e7b25 FEAT_2: Cart Balancer (Assessment)_4040 - Correlation: 1.0
# 504: FEAT_1: 6088b756 FEAT_2: Dino Dive_2070 - Correlation: 0.9999999999999998
# 505: FEAT_1: 65abac75 FEAT_2: Air Show_4010 - Correlation: 1.0
# 506: FEAT_1: dcb55a27 FEAT_2: Air Show_4110 - Correlation: 0.9999999999999999
# 507: FEAT_1: 37937459 FEAT_2: Sandcastle Builder (Activity)_4090 - Correlation: 0.9999999999999998
# 508: FEAT_1: 3ee399c3 FEAT_2: Cauldron Filler (Assessment)_4070 - Correlation: 0.9999999999999999
# 509: FEAT_1: fcfdffb6 FEAT_2: Flower Waterer (Activity)_4022 - Correlation: 0.9999999999999999
# 510: FEAT_1: 461eace6 FEAT_2: Egg Dropper (Activity)_4020 - Correlation: 1.0
# 511: FEAT_1: 63f13dd7 FEAT_2: Chow Time_2020 - Correlation: 1.0
# 512: FEAT_1: e7e44842 FEAT_2: Watering Hole (Activity)_4090 - Correlation: 1.0
# 513: FEAT_1: 9e34ea74 FEAT_2: Egg Dropper (Activity)_4070 - Correlation: 1.0
# 514: FEAT_1: 25fa8af4 FEAT_2: Mushroom Sorter (Assessment)_4100 - Correlation: 1.0
# 515: FEAT_1: 1340b8d7 FEAT_2: 4220 - Correlation: 1.0
# 516: FEAT_1: 1340b8d7 FEAT_2: Bubble Bath_4220 - Correlation: 1.0
# 517: FEAT_1: 9ed8f6da FEAT_2: Dino Drink_2075 - Correlation: 1.0
# 518: FEAT_1: 0db6d71d FEAT_2: Chest Sorter (Assessment)_4020 - Correlation: 0.9999999999999998
# 519: FEAT_1: 67aa2ada FEAT_2: Leaf Leader_4090 - Correlation: 1.0
# 520: FEAT_1: 91561152 FEAT_2: Cauldron Filler (Assessment)_4025 - Correlation: 1.0
# 521: FEAT_1: 3b2048ee FEAT_2: Leaf Leader_4095 - Correlation: 0.9999999999999998
# 522: FEAT_1: acf5c23f FEAT_2: Cart Balancer (Assessment)_4070 - Correlation: 1.0
# 523: FEAT_1: 51102b85 FEAT_2: Bird Measurer (Assessment)_4030 - Correlation: 1.0
# 524: FEAT_1: 795e4a37 FEAT_2: Cart Balancer (Assessment)_3010 - Correlation: 1.0
# 525: FEAT_1: 99ea62f3 FEAT_2: Bubble Bath_2083 - Correlation: 1.0
# 526: FEAT_1: 6043a2b4 FEAT_2: All Star Sorting_4090 - Correlation: 1.0
# 527: FEAT_1: 6aeafed4 FEAT_2: Bubble Bath_4090 - Correlation: 1.0
# 528: FEAT_1: 8af75982 FEAT_2: Happy Camel_4020 - Correlation: 1.0
# 529: FEAT_1: 3110 FEAT_2: 3010 - Correlation: 0.9998806305811936
# 530: FEAT_1: 3120 FEAT_2: 3020 - Correlation: 0.9998524456510475
# 531: FEAT_1: 3121 FEAT_2: 3021 - Correlation: 0.9999037632424913
# 532: FEAT_1: var_event_id FEAT_2: var_title_event_code - Correlation: 0.9994843994011452

# %%
y = train_en['accuracy_group']
X = train_en.drop(columns=(to_remove + ['accuracy_group', 'installation_id']), axis=1)
test_predict = test_en.drop(columns=(to_remove + ['accuracy_group', 'installation_id']), axis=1)

# %%
def NN_model(X_train, y_train, X_val, y_val):
    
    model = tf.keras.models.Sequential([
        tf.keras.layers.Input(shape=(X_train.shape[1],)),
        tf.keras.layers.Dense(200, activation='relu'),
        tf.keras.layers.LayerNormalization(),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(100, activation='relu'),
        tf.keras.layers.LayerNormalization(),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(50, activation='relu'),
        tf.keras.layers.LayerNormalization(),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(25, activation='relu'),
        tf.keras.layers.LayerNormalization(),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(1, activation='relu')
    ])
    
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=4e-4),
                  loss='mse')
    print(model.summary())
    save_best = tf.keras.callbacks.ModelCheckpoint('nn_model.w8', save_weights_only=True,
                                                      save_best_only=True, verbose=1)
    early_stop = tf.keras.callbacks.EarlyStopping(patience=20)
    model.fit(X_train, y_train,
              validation_data=(X_val, y_val),
              epochs=100,
              callbacks=[save_best, early_stop],
              verbose=100)
    return model

# %%
n_splits = 5
cv = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=46)
models = []
for fold, (train_idx, val_idx) in enumerate(cv.split(X, y)):
    X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_train, y_val = y.iloc[train_idx], y.iloc[val_idx]
    model = NN_model(X_train, y_train, X_val, y_val)
    models.append(model)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_5 (Dense)              (None, 200)               85200
# _________________________________________________________________
# layer_normalization_4 (Layer (None, 200)               400
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 200)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 100)               20100
# _________________________________________________________________
# layer_normalization_5 (Layer (None, 100)               200
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 50)                5050
# _________________________________________________________________
# layer_normalization_6 (Layer (None, 50)                100
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 25)                1275
# _________________________________________________________________
# layer_normalization_7 (Layer (None, 25)                50
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 25)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 26
# =================================================================
# Total params: 112,401
# Trainable params: 112,401
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 16950 samples, validate on 4240 samples
# Epoch 1/100
#
# Epoch 00001: val_loss improved from inf to 1.75322, saving model to nn_model.w8
# Epoch 2/100
#
# Epoch 00002: val_loss improved from 1.75322 to 1.71254, saving model to nn_model.w8
# Epoch 3/100
#
# Epoch 00003: val_loss improved from 1.71254 to 1.64897, saving model to nn_model.w8
# Epoch 4/100
#
# Epoch 00004: val_loss improved from 1.64897 to 1.60650, saving model to nn_model.w8
# Epoch 5/100
#
# Epoch 00005: val_loss improved from 1.60650 to 1.58622, saving model to nn_model.w8
# Epoch 6/100
#
# Epoch 00006: val_loss improved from 1.58622 to 1.57114, saving model to nn_model.w8
# Epoch 7/100
#
# Epoch 00007: val_loss improved from 1.57114 to 1.54740, saving model to nn_model.w8
# Epoch 8/100
#
# Epoch 00008: val_loss improved from 1.54740 to 1.54050, saving model to nn_model.w8
# Epoch 9/100
#
# Epoch 00009: val_loss improved from 1.54050 to 1.53646, saving model to nn_model.w8
# Epoch 10/100
#
# Epoch 00010: val_loss improved from 1.53646 to 1.52720, saving model to nn_model.w8
# Epoch 11/100
#
# Epoch 00011: val_loss improved from 1.52720 to 1.50658, saving model to nn_model.w8
# Epoch 12/100
#
# Epoch 00012: val_loss improved from 1.50658 to 1.50613, saving model to nn_model.w8
# Epoch 13/100
#
# Epoch 00013: val_loss did not improve from 1.50613
# Epoch 14/100
#
# Epoch 00014: val_loss improved from 1.50613 to 1.49425, saving model to nn_model.w8
# Epoch 15/100
#
# Epoch 00015: val_loss did not improve from 1.49425
# Epoch 16/100
#
# Epoch 00016: val_loss improved from 1.49425 to 1.48897, saving model to nn_model.w8
# Epoch 17/100
#
# Epoch 00017: val_loss did not improve from 1.48897
# Epoch 18/100
#
# Epoch 00018: val_loss improved from 1.48897 to 1.48398, saving model to nn_model.w8
# Epoch 19/100
#
# Epoch 00019: val_loss improved from 1.48398 to 1.48313, saving model to nn_model.w8
# Epoch 20/100
#
# Epoch 00020: val_loss did not improve from 1.48313
# Epoch 21/100
#
# Epoch 00021: val_loss improved from 1.48313 to 1.47534, saving model to nn_model.w8
# Epoch 22/100
#
# Epoch 00022: val_loss did not improve from 1.47534
# Epoch 23/100
#
# Epoch 00023: val_loss improved from 1.47534 to 1.46619, saving model to nn_model.w8
# Epoch 24/100
#
# Epoch 00024: val_loss did not improve from 1.46619
# Epoch 25/100
#
# Epoch 00025: val_loss did not improve from 1.46619
# Epoch 26/100
#
# Epoch 00026: val_loss did not improve from 1.46619
# Epoch 27/100
#
# Epoch 00027: val_loss did not improve from 1.46619
# Epoch 28/100
#
# Epoch 00028: val_loss did not improve from 1.46619
# Epoch 29/100
#
# Epoch 00029: val_loss did not improve from 1.46619
# Epoch 30/100
#
# Epoch 00030: val_loss improved from 1.46619 to 1.45921, saving model to nn_model.w8
# Epoch 31/100
#
# Epoch 00031: val_loss did not improve from 1.45921
# Epoch 32/100
#
# Epoch 00032: val_loss did not improve from 1.45921
# Epoch 33/100
#
# Epoch 00033: val_loss did not improve from 1.45921
# Epoch 34/100
#
# Epoch 00034: val_loss did not improve from 1.45921
# Epoch 35/100
#
# Epoch 00035: val_loss did not improve from 1.45921
# Epoch 36/100
#
# Epoch 00036: val_loss did not improve from 1.45921
# Epoch 37/100
#
# Epoch 00037: val_loss did not improve from 1.45921
# Epoch 38/100
#
# Epoch 00038: val_loss did not improve from 1.45921
# Epoch 39/100
#
# Epoch 00039: val_loss did not improve from 1.45921
# Epoch 40/100
#
# Epoch 00040: val_loss did not improve from 1.45921
# Epoch 41/100
#
# Epoch 00041: val_loss did not improve from 1.45921
# Epoch 42/100
#
# Epoch 00042: val_loss did not improve from 1.45921
# Epoch 43/100
#
# Epoch 00043: val_loss did not improve from 1.45921
# Epoch 44/100
#
# Epoch 00044: val_loss did not improve from 1.45921
# Epoch 45/100
#
# Epoch 00045: val_loss did not improve from 1.45921
# Epoch 46/100
#
# Epoch 00046: val_loss improved from 1.45921 to 1.45895, saving model to nn_model.w8
# Epoch 47/100
#
# Epoch 00047: val_loss did not improve from 1.45895
# Epoch 48/100
#
# Epoch 00048: val_loss did not improve from 1.45895
# Epoch 49/100
#
# Epoch 00049: val_loss did not improve from 1.45895
# Epoch 50/100
#
# Epoch 00050: val_loss did not improve from 1.45895
# Epoch 51/100
#
# Epoch 00051: val_loss did not improve from 1.45895
# Epoch 52/100
#
# Epoch 00052: val_loss did not improve from 1.45895
# Epoch 53/100
#
# Epoch 00053: val_loss did not improve from 1.45895
# Epoch 54/100
#
# Epoch 00054: val_loss did not improve from 1.45895
# Epoch 55/100
#
# Epoch 00055: val_loss did not improve from 1.45895
# Epoch 56/100
#
# Epoch 00056: val_loss did not improve from 1.45895
# Epoch 57/100
#
# Epoch 00057: val_loss did not improve from 1.45895
# Epoch 58/100
#
# Epoch 00058: val_loss did not improve from 1.45895
# Epoch 59/100
#
# Epoch 00059: val_loss did not improve from 1.45895
# Epoch 60/100
#
# Epoch 00060: val_loss did not improve from 1.45895
# Epoch 61/100
#
# Epoch 00061: val_loss did not improve from 1.45895
# Epoch 62/100
#
# Epoch 00062: val_loss did not improve from 1.45895
# Epoch 63/100
#
# Epoch 00063: val_loss did not improve from 1.45895
# Epoch 64/100
#
# Epoch 00064: val_loss did not improve from 1.45895
# Epoch 65/100
#
# Epoch 00065: val_loss did not improve from 1.45895
# Epoch 66/100
#
# Epoch 00066: val_loss did not improve from 1.45895
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_10 (Dense)             (None, 200)               85200
# _________________________________________________________________
# layer_normalization_8 (Layer (None, 200)               400
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 200)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 100)               20100
# _________________________________________________________________
# layer_normalization_9 (Layer (None, 100)               200
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 50)                5050
# _________________________________________________________________
# layer_normalization_10 (Laye (None, 50)                100
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 50)                0
# _________________________________________________________________
# dense_13 (Dense)             (None, 25)                1275
# _________________________________________________________________
# layer_normalization_11 (Laye (None, 25)                50
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 25)                0
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 26
# =================================================================
# Total params: 112,401
# Trainable params: 112,401
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 16951 samples, validate on 4239 samples
# Epoch 1/100
#
# Epoch 00001: val_loss improved from inf to 1.79178, saving model to nn_model.w8
# Epoch 2/100
#
# Epoch 00002: val_loss improved from 1.79178 to 1.70393, saving model to nn_model.w8
# Epoch 3/100
#
# Epoch 00003: val_loss improved from 1.70393 to 1.66981, saving model to nn_model.w8
# Epoch 4/100
#
# Epoch 00004: val_loss improved from 1.66981 to 1.60433, saving model to nn_model.w8
# Epoch 5/100
#
# Epoch 00005: val_loss improved from 1.60433 to 1.58006, saving model to nn_model.w8
# Epoch 6/100
#
# Epoch 00006: val_loss improved from 1.58006 to 1.54936, saving model to nn_model.w8
# Epoch 7/100
#
# Epoch 00007: val_loss improved from 1.54936 to 1.54706, saving model to nn_model.w8
# Epoch 8/100
#
# Epoch 00008: val_loss improved from 1.54706 to 1.52930, saving model to nn_model.w8
# Epoch 9/100
#
# Epoch 00009: val_loss improved from 1.52930 to 1.52441, saving model to nn_model.w8
# Epoch 10/100
#
# Epoch 00010: val_loss did not improve from 1.52441
# Epoch 11/100
#
# Epoch 00011: val_loss improved from 1.52441 to 1.52217, saving model to nn_model.w8
# Epoch 12/100
#
# Epoch 00012: val_loss improved from 1.52217 to 1.50802, saving model to nn_model.w8
# Epoch 13/100
#
# Epoch 00013: val_loss improved from 1.50802 to 1.49313, saving model to nn_model.w8
# Epoch 14/100
#
# Epoch 00014: val_loss improved from 1.49313 to 1.48566, saving model to nn_model.w8
# Epoch 15/100
#
# Epoch 00015: val_loss did not improve from 1.48566
# Epoch 16/100
#
# Epoch 00016: val_loss improved from 1.48566 to 1.48144, saving model to nn_model.w8
# Epoch 17/100
#
# Epoch 00017: val_loss did not improve from 1.48144
# Epoch 18/100
#
# Epoch 00018: val_loss improved from 1.48144 to 1.47271, saving model to nn_model.w8
# Epoch 19/100
#
# Epoch 00019: val_loss did not improve from 1.47271
# Epoch 20/100
#
# Epoch 00020: val_loss did not improve from 1.47271
# Epoch 21/100
#
# Epoch 00021: val_loss improved from 1.47271 to 1.46881, saving model to nn_model.w8
# Epoch 22/100
#
# Epoch 00022: val_loss improved from 1.46881 to 1.46038, saving model to nn_model.w8
# Epoch 23/100
#
# Epoch 00023: val_loss did not improve from 1.46038
# Epoch 24/100
#
# Epoch 00024: val_loss did not improve from 1.46038
# Epoch 25/100
#
# Epoch 00025: val_loss did not improve from 1.46038
# Epoch 26/100
#
# Epoch 00026: val_loss did not improve from 1.46038
# Epoch 27/100
#
# Epoch 00027: val_loss did not improve from 1.46038
# Epoch 28/100
#
# Epoch 00028: val_loss improved from 1.46038 to 1.44736, saving model to nn_model.w8
# Epoch 29/100
#
# Epoch 00029: val_loss did not improve from 1.44736
# Epoch 30/100
#
# Epoch 00030: val_loss did not improve from 1.44736
# Epoch 31/100
#
# Epoch 00031: val_loss improved from 1.44736 to 1.44172, saving model to nn_model.w8
# Epoch 32/100
#
# Epoch 00032: val_loss did not improve from 1.44172
# Epoch 33/100
#
# Epoch 00033: val_loss did not improve from 1.44172
# Epoch 34/100
#
# Epoch 00034: val_loss did not improve from 1.44172
# Epoch 35/100
#
# Epoch 00035: val_loss improved from 1.44172 to 1.44047, saving model to nn_model.w8
# Epoch 36/100
#
# Epoch 00036: val_loss did not improve from 1.44047
# Epoch 37/100
#
# Epoch 00037: val_loss did not improve from 1.44047
# Epoch 38/100
#
# Epoch 00038: val_loss did not improve from 1.44047
# Epoch 39/100
#
# Epoch 00039: val_loss did not improve from 1.44047
# Epoch 40/100
#
# Epoch 00040: val_loss did not improve from 1.44047
# Epoch 41/100
#
# Epoch 00041: val_loss did not improve from 1.44047
# Epoch 42/100
#
# Epoch 00042: val_loss did not improve from 1.44047
# Epoch 43/100
#
# Epoch 00043: val_loss did not improve from 1.44047
# Epoch 44/100
#
# Epoch 00044: val_loss did not improve from 1.44047
# Epoch 45/100
#
# Epoch 00045: val_loss did not improve from 1.44047
# Epoch 46/100
#
# Epoch 00046: val_loss did not improve from 1.44047
# Epoch 47/100
#
# Epoch 00047: val_loss did not improve from 1.44047
# Epoch 48/100
#
# Epoch 00048: val_loss did not improve from 1.44047
# Epoch 49/100
#
# Epoch 00049: val_loss did not improve from 1.44047
# Epoch 50/100
#
# Epoch 00050: val_loss did not improve from 1.44047
# Epoch 51/100
#
# Epoch 00051: val_loss did not improve from 1.44047
# Epoch 52/100
#
# Epoch 00052: val_loss did not improve from 1.44047
# Epoch 53/100
#
# Epoch 00053: val_loss did not improve from 1.44047
# Epoch 54/100
#
# Epoch 00054: val_loss did not improve from 1.44047
# Epoch 55/100
#
# Epoch 00055: val_loss did not improve from 1.44047
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_15 (Dense)             (None, 200)               85200
# _________________________________________________________________
# layer_normalization_12 (Laye (None, 200)               400
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 200)               0
# _________________________________________________________________
# dense_16 (Dense)             (None, 100)               20100
# _________________________________________________________________
# layer_normalization_13 (Laye (None, 100)               200
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 100)               0
# _________________________________________________________________
# dense_17 (Dense)             (None, 50)                5050
# _________________________________________________________________
# layer_normalization_14 (Laye (None, 50)                100
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 50)                0
# _________________________________________________________________
# dense_18 (Dense)             (None, 25)                1275
# _________________________________________________________________
# layer_normalization_15 (Laye (None, 25)                50
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 25)                0
# _________________________________________________________________
# dense_19 (Dense)             (None, 1)                 26
# =================================================================
# Total params: 112,401
# Trainable params: 112,401
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 16953 samples, validate on 4237 samples
# Epoch 1/100
#
# Epoch 00001: val_loss improved from inf to 1.77727, saving model to nn_model.w8
# Epoch 2/100
#
# Epoch 00002: val_loss improved from 1.77727 to 1.73711, saving model to nn_model.w8
# Epoch 3/100
#
# Epoch 00003: val_loss improved from 1.73711 to 1.67475, saving model to nn_model.w8
# Epoch 4/100
#
# Epoch 00004: val_loss improved from 1.67475 to 1.61113, saving model to nn_model.w8
# Epoch 5/100
#
# Epoch 00005: val_loss improved from 1.61113 to 1.59460, saving model to nn_model.w8
# Epoch 6/100
#
# Epoch 00006: val_loss improved from 1.59460 to 1.58765, saving model to nn_model.w8
# Epoch 7/100
#
# Epoch 00007: val_loss improved from 1.58765 to 1.56926, saving model to nn_model.w8
# Epoch 8/100
#
# Epoch 00008: val_loss improved from 1.56926 to 1.55995, saving model to nn_model.w8
# Epoch 9/100
# Epoch 00009: val_loss improved from 1.55995 to 1.55897, saving model to nn_model.w8
# Epoch 10/100
#
# Epoch 00010: val_loss improved from 1.55897 to 1.53430, saving model to nn_model.w8
# Epoch 11/100
#
# Epoch 00011: val_loss did not improve from 1.53430
# Epoch 12/100
#
# Epoch 00012: val_loss improved from 1.53430 to 1.52917, saving model to nn_model.w8
# Epoch 13/100
#
# Epoch 00013: val_loss improved from 1.52917 to 1.51918, saving model to nn_model.w8
# Epoch 14/100
#
# Epoch 00014: val_loss improved from 1.51918 to 1.51757, saving model to nn_model.w8
# Epoch 15/100
#
# Epoch 00015: val_loss did not improve from 1.51757
# Epoch 16/100
#
# Epoch 00016: val_loss improved from 1.51757 to 1.51241, saving model to nn_model.w8
# Epoch 17/100
#
# Epoch 00017: val_loss did not improve from 1.51241
# Epoch 18/100
#
# Epoch 00018: val_loss did not improve from 1.51241
# Epoch 19/100
#
# Epoch 00019: val_loss did not improve from 1.51241
# Epoch 20/100
#
# Epoch 00020: val_loss improved from 1.51241 to 1.49350, saving model to nn_model.w8
# Epoch 21/100
#
# Epoch 00021: val_loss did not improve from 1.49350
# Epoch 22/100
#
# Epoch 00022: val_loss did not improve from 1.49350
# Epoch 23/100
#
# Epoch 00023: val_loss improved from 1.49350 to 1.48035, saving model to nn_model.w8
# Epoch 24/100
#
# Epoch 00024: val_loss did not improve from 1.48035
# Epoch 25/100
#
# Epoch 00025: val_loss did not improve from 1.48035
# Epoch 26/100
#
# Epoch 00026: val_loss did not improve from 1.48035
# Epoch 27/100
#
# Epoch 00027: val_loss improved from 1.48035 to 1.47474, saving model to nn_model.w8
# Epoch 28/100
#
# Epoch 00028: val_loss did not improve from 1.47474
# Epoch 29/100
#
# Epoch 00029: val_loss did not improve from 1.47474
# Epoch 30/100
#
# Epoch 00030: val_loss did not improve from 1.47474
# Epoch 31/100
#
# Epoch 00031: val_loss improved from 1.47474 to 1.47243, saving model to nn_model.w8
# Epoch 32/100
#
# Epoch 00032: val_loss did not improve from 1.47243
# Epoch 33/100
#
# Epoch 00033: val_loss improved from 1.47243 to 1.46717, saving model to nn_model.w8
# Epoch 34/100
#
# Epoch 00034: val_loss did not improve from 1.46717
# Epoch 35/100
#
# Epoch 00035: val_loss did not improve from 1.46717
# Epoch 36/100
#
# Epoch 00036: val_loss did not improve from 1.46717
# Epoch 37/100
#
# Epoch 00037: val_loss did not improve from 1.46717
# Epoch 38/100
#
# Epoch 00038: val_loss did not improve from 1.46717
# Epoch 39/100
#
# Epoch 00039: val_loss did not improve from 1.46717
# Epoch 40/100
#
# Epoch 00040: val_loss did not improve from 1.46717
# Epoch 41/100
#
# Epoch 00041: val_loss did not improve from 1.46717
# Epoch 42/100
#
# Epoch 00042: val_loss did not improve from 1.46717
# Epoch 43/100
#
# Epoch 00043: val_loss did not improve from 1.46717
# Epoch 44/100
#
# Epoch 00044: val_loss did not improve from 1.46717
# Epoch 45/100
#
# Epoch 00045: val_loss improved from 1.46717 to 1.46032, saving model to nn_model.w8
# Epoch 46/100
#
# Epoch 00046: val_loss did not improve from 1.46032
# Epoch 47/100
#
# Epoch 00047: val_loss did not improve from 1.46032
# Epoch 48/100
#
# Epoch 00048: val_loss did not improve from 1.46032
# Epoch 49/100
#
# Epoch 00049: val_loss did not improve from 1.46032
# Epoch 50/100
#
# Epoch 00050: val_loss did not improve from 1.46032
# Epoch 51/100
#
# Epoch 00051: val_loss did not improve from 1.46032
# Epoch 52/100
#
# Epoch 00052: val_loss did not improve from 1.46032
# Epoch 53/100
#
# Epoch 00053: val_loss did not improve from 1.46032
# Epoch 54/100
#
# Epoch 00054: val_loss did not improve from 1.46032
# Epoch 55/100
#
# Epoch 00055: val_loss improved from 1.46032 to 1.45444, saving model to nn_model.w8
# Epoch 56/100
#
# Epoch 00056: val_loss did not improve from 1.45444
# Epoch 57/100
#
# Epoch 00057: val_loss did not improve from 1.45444
# Epoch 58/100
#
# Epoch 00058: val_loss did not improve from 1.45444
# Epoch 59/100
#
# Epoch 00059: val_loss did not improve from 1.45444
# Epoch 60/100
#
# Epoch 00060: val_loss did not improve from 1.45444
# Epoch 61/100
#
# Epoch 00061: val_loss did not improve from 1.45444
# Epoch 62/100
#
# Epoch 00062: val_loss did not improve from 1.45444
# Epoch 63/100
#
# Epoch 00063: val_loss did not improve from 1.45444
# Epoch 64/100
#
# Epoch 00064: val_loss did not improve from 1.45444
# Epoch 65/100
#
# Epoch 00065: val_loss did not improve from 1.45444
# Epoch 66/100
#
# Epoch 00066: val_loss did not improve from 1.45444
# Epoch 67/100
#
# Epoch 00067: val_loss did not improve from 1.45444
# Epoch 68/100
#
# Epoch 00068: val_loss did not improve from 1.45444
# Epoch 69/100
#
# Epoch 00069: val_loss did not improve from 1.45444
# Epoch 70/100
#
# Epoch 00070: val_loss did not improve from 1.45444
# Epoch 71/100
#
# Epoch 00071: val_loss did not improve from 1.45444
# Epoch 72/100
#
# Epoch 00072: val_loss did not improve from 1.45444
# Epoch 73/100
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-570396ad7289> in <module>
#       5     X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
#       6     y_train, y_val = y.iloc[train_idx], y.iloc[val_idx]
# ----> 7     model = NN_model(X_train, y_train, X_val, y_val)
#       8     models.append(model)
#
# <ipython-input-25-747a1bd41f4d> in NN_model(X_train, y_train, X_val, y_val)
#      28               epochs=100,
#      29               callbacks=[save_best, early_stop],
# ---> 30               verbose=100)
#      31     return model
#
# ~\AppData\Local\anaconda3\envs\tf-20-gpu\lib\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     641         max_queue_size=max_queue_size,
#     642         workers=workers,
# --> 643         use_multiprocessing=use_multiprocessing)
#     644
#     645   def evaluate(self,
#
# ~\AppData\Local\anaconda3\envs\tf-20-gpu\lib\site-packages\tensorflow\python\keras\engine\training_arrays.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, **kwargs)
#     662         validation_steps=validation_steps,
#     663         validation_freq=validation_freq,
# --> 664         steps_name='steps_per_epoch')
#     665
#     666   def evaluate(self,
#
# ~\AppData\Local\anaconda3\envs\tf-20-gpu\lib\site-packages\tensorflow\python\keras\engine\training_arrays.py in model_iteration(model, inputs, targets, sample_weights, batch_size, epochs, verbose, callbacks, val_inputs, val_targets, val_sample_weights, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq, mode, validation_in_fit, prepared_feed_values_from_dataset, steps_name, **kwargs)
#     381
#     382         # Get outputs.
# --> 383         batch_outs = f(ins_batch)
#     384         if not isinstance(batch_outs, list):
#     385           batch_outs = [batch_outs]
#
# ~\AppData\Local\anaconda3\envs\tf-20-gpu\lib\site-packages\tensorflow\python\keras\backend.py in __call__(self, inputs)
#    3502               'You must feed a value for placeholder %s' % (tensor,))
#    3503       if not isinstance(value, ops.Tensor):
# -> 3504         value = ops.convert_to_tensor(value, dtype=tensor.dtype)
#    3505       if value.dtype != tensor.dtype:
#    3506         # Temporary workaround due to `convert_to_tensor` not casting floats.
#
# ~\AppData\Local\anaconda3\envs\tf-20-gpu\lib\site-packages\tensorflow\python\framework\ops.py in convert_to_tensor(value, dtype, name, preferred_dtype, dtype_hint)
#    1098   preferred_dtype = deprecation.deprecated_argument_lookup(
#    1099       "dtype_hint", dtype_hint, "preferred_dtype", preferred_dtype)
# -> 1100   return convert_to_tensor_v2(value, dtype, preferred_dtype, name)
#    1101
#    1102
#
# ~\AppData\Local\anaconda3\envs\tf-20-gpu\lib\site-packages\tensorflow\python\framework\ops.py in convert_to_tensor_v2(value, dtype, dtype_hint, name)
#    1156       name=name,
#    1157       preferred_dtype=dtype_hint,
# -> 1158       as_ref=False)
#    1159
#    1160
#
# ~\AppData\Local\anaconda3\envs\tf-20-gpu\lib\site-packages\tensorflow\python\framework\ops.py in internal_convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, ctx, accept_symbolic_tensors, accept_composite_tensors)
#    1235
#    1236     if ret is None:
# -> 1237       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1238
#    1239     if ret is NotImplemented:
#
# ~\AppData\Local\anaconda3\envs\tf-20-gpu\lib\site-packages\tensorflow\python\framework\constant_op.py in _constant_tensor_conversion_function(v, dtype, name, as_ref)
#     303                                          as_ref=False):
#     304   _ = as_ref
# --> 305   return constant(v, dtype=dtype, name=name)
#     306
#     307
#
# ~\AppData\Local\anaconda3\envs\tf-20-gpu\lib\site-packages\tensorflow\python\framework\constant_op.py in constant(value, dtype, shape, name)
#     244   """
#     245   return _constant_impl(value, dtype, shape, name, verify_shape=False,
# --> 246                         allow_broadcast=True)
#     247
#     248
#
# ~\AppData\Local\anaconda3\envs\tf-20-gpu\lib\site-packages\tensorflow\python\framework\constant_op.py in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     252   ctx = context.context()
#     253   if ctx.executing_eagerly():
# --> 254     t = convert_to_eager_tensor(value, ctx, dtype)
#     255     if shape is None:
#     256       return t
#
# ~\AppData\Local\anaconda3\envs\tf-20-gpu\lib\site-packages\tensorflow\python\framework\constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
#     113     return t
#     114   else:
# --> 115     return ops.EagerTensor(value, handle, device, dtype)
#     116
#     117
#
# KeyboardInterrupt:

# %%
pred_ensemble = np.zeros((test_predict.shape[0], 1))
for model in models:
    pred = model.predict(test_predict, verbose=0)
    pred_ensemble += pred
final_pred = pred_ensemble / len(models)

# %%
dist = Counter(train_en['accuracy_group'])
for k in dist:
    dist[k] /= len(train_en)
train_en['accuracy_group'].hist()

acum = 0
bound = {}
for i in range(3):
    acum += dist[i]
    bound[i] = np.percentile(final_pred, acum * 100)
print(bound)

def classify(x):
    if x <= bound[0]:
        return 0
    elif x <= bound[1]:
        return 1
    elif x <= bound[2]:
        return 2
    else:
        return 3
    
final_pred = np.array(list(map(classify, final_pred)))

sample_submission['accuracy_group'] = final_pred.astype(int)
sample_submission.to_csv('submission.csv', index=False)
sample_submission['accuracy_group'].value_counts(normalize=True)
